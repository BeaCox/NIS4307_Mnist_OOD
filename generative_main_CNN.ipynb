# %%
import torch
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms
from torch import nn, optim
from torch.nn import functional as F
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np
from tqdm import tqdm

# %%
# 超参数定义
num_epochs = 10
batch_size = 64
learning_rate = 8e-3
thresholds_percent = 0.8
KLD_weight = 0.4
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# 数据增强
transform = transforms.Compose([
    transforms.RandomRotation(25),
    transforms.ToTensor(),
])
transform2 = transforms.Compose([
    transforms.ToTensor(),
])

# 加载全部数据
mnist_data = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_data2 = datasets.MNIST(root='./data', train=False, download=True, transform=transform2)
# 合并数据集
mnist_data = torch.utils.data.ConcatDataset([mnist_data, mnist_data2])
# 获取数据集的大小
total_size = len(mnist_data)
# 计算训练数据集的大小（80%）
train_size = int(total_size * 0.8)
# 计算测试数据集的大小（20%）
test_size = total_size - train_size
# 分割数据集
train_data, test_data = torch.utils.data.random_split(mnist_data, [train_size, test_size])

# 对于每个数字，创建一个数据加载器
digit_train_loaders = [DataLoader(Subset(train_data, 
                       [idx for idx, (_, target) in enumerate(train_data) if target == i]),
                       batch_size=batch_size, shuffle=True) for i in range(10)]

# 对于每个数字，创建一个测试数据加载器
digit_test_loaders = [DataLoader(Subset(test_data, 
                       [idx for idx, (_, target) in enumerate(test_data) if target == i]),
                       batch_size=batch_size, shuffle=True) for i in range(10)]

# %%
class VAE_CNN(nn.Module):
    def __init__(self):
        super(VAE_CNN, self).__init__()

        # Encoder
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1)
        self.fc_mu = nn.Linear(64 * 7 * 7, 20) 
        self.fc_logvar = nn.Linear(64 * 7 * 7, 20) 

        # Decoder
        self.fc_decode = nn.Linear(20, 64 * 7 * 7)
        self.deconv1 = nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=1, output_padding=1)
        self.deconv2 = nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=1, output_padding=1)
        self.deconv3 = nn.ConvTranspose2d(16, 1, kernel_size=3, stride=1, padding=1)

    def encode(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = x.view(x.shape[0], -1)
        return self.fc_mu(x), self.fc_logvar(x)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mu + eps*std

    def decode(self, z):
        z = F.relu(self.fc_decode(z))
        z = z.view(z.shape[0], 64, 7, 7)
        z = F.relu(self.deconv1(z))
        z = F.relu(self.deconv2(z))
        return torch.sigmoid(self.deconv3(z))

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar

# %%
# 用于存储每个数字对应的模型
vaes = [VAE_CNN().to(device) for _ in range(10)]
optimizers = [optim.Adamax(vae.parameters(), lr=learning_rate) for vae in vaes]

# %%
def loss_function(recon_x, x, mu, logvar): # 重构损失 + KL散度
    BCE = F.binary_cross_entropy(recon_x, x.view(-1, 1, 28, 28), reduction='sum')
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return (1-KLD_weight)*BCE + KLD_weight*KLD

# %%
def train():
    for epoch in range(num_epochs):
        for i in range(10):
            for data in digit_train_loaders[i]:
                img, _ = data
                img = img.to(device)
                recon_batch, mu, logvar = vaes[i](img)
                loss = loss_function(recon_batch, img, mu, logvar)
                print('number:{}:epoch [{}/{}], loss:{:.4f}'.format(i,epoch + 1, num_epochs, loss.item()))
                optimizers[i].zero_grad()
                loss.backward()
                optimizers[i].step()

def compute_reconstruction_error(data, model): # 计算重构误差
    with torch.no_grad():
        recon_data, _, _ = model(data)
        recon_error = ((recon_data - data)**2).sum(dim=(1,2,3))
        return recon_error.cpu().numpy()

# %%
def test():
    # 加载FashionMNIST测试数据作为OOD样本
    fashion_mnist_data = datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)
    fashion_mnist_loader = DataLoader(fashion_mnist_data, batch_size=batch_size, shuffle=False)

    # 对于每个测试样本，计算其对于每个模型的重构误差
    test_errors = []
    # 计算FashionMNIST样本在每个模型上的重构误差
    fashion_errors = []
    with torch.no_grad():
        for data, _ in fashion_mnist_loader:
            img = data.to(device)
            errors = np.stack([compute_reconstruction_error(img, vae) for vae in vaes], axis=-1)
            fashion_errors.extend(errors)
    fashion_errors = np.array(fashion_errors)

    # 计算阈值，设置为训练集上的thresholds_percent重构误差百分位数
    thresholds = [np.percentile([compute_reconstruction_error(data, vaes[i]).max()
                 for data, _ in digit_train_loaders[i]], thresholds_percent) for i in range(10)]
    # 对FashionMNIST样本进行分类
    fashion_pred = np.argmin(fashion_errors, axis=1)
    # 如果重构误差大于阈值，则判断为OOD
    fashion_pred = [pred if error[pred] <= thresholds[pred] else 10 for pred, error in zip(fashion_pred, fashion_errors)]
    # 计算OOD检测的准确率，精确度，召回率和F1分数
    fashion_true = [10] * len(fashion_pred)  # 10表示OOD
    accuracy = accuracy_score(fashion_true, fashion_pred)
    precision = precision_score(fashion_true, fashion_pred, average='weighted')
    recall = recall_score(fashion_true, fashion_pred, average='weighted')
    f1 = f1_score(fashion_true, fashion_pred, average='weighted')
    print(f"OOD Detection: Accuracy: {accuracy:.2f}, Precision: {precision:.2f}, Recall: {recall:.2f}, F1-score: {f1:.2f}")

    y_true = []
    test_errors = []
    with torch.no_grad():
        for i in range(10):
            for data, targets in digit_test_loaders[i]:
                img = data.to(device)
                errors = np.stack([compute_reconstruction_error(img, vae) for vae in vaes], axis=-1)
                test_errors.extend(errors)
                y_true.extend(targets.numpy())
    test_errors = np.array(test_errors)

    # 对于每个测试样本，将其分类为重构误差最小的类别
    y_pred = np.argmin(test_errors, axis=1)

    # 计算accuracy，precision，recall和F1-score
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    f1 = f1_score(y_true, y_pred, average='weighted')

    print(f"In MNIST:Accuracy: {accuracy:.2f}, Precision: {precision:.2f}, Recall: {recall:.2f}, F1-score: {f1:.2f}")

# %%
train()
# Out:
# number:0:epoch [1/10], loss:21616.8809
# number:0:epoch [1/10], loss:17094.8398
# number:0:epoch [1/10], loss:45504.1523
# number:0:epoch [1/10], loss:16052.3398
# number:0:epoch [1/10], loss:16168.5703
# number:0:epoch [1/10], loss:17261.8477
# number:0:epoch [1/10], loss:17868.9355
# number:0:epoch [1/10], loss:17990.3438
# number:0:epoch [1/10], loss:18083.0215
# number:0:epoch [1/10], loss:17643.5664
# number:0:epoch [1/10], loss:17596.5020
# number:0:epoch [1/10], loss:17082.6191
# number:0:epoch [1/10], loss:16619.9590
# number:0:epoch [1/10], loss:16057.3506
# number:0:epoch [1/10], loss:15616.2285
# number:0:epoch [1/10], loss:14888.9131
# number:0:epoch [1/10], loss:14842.8906
# number:0:epoch [1/10], loss:14300.3477
# number:0:epoch [1/10], loss:13802.8613
# number:0:epoch [1/10], loss:13725.4512
# number:0:epoch [1/10], loss:13196.3369
# number:0:epoch [1/10], loss:14290.7588
# number:0:epoch [1/10], loss:13371.7227
# number:0:epoch [1/10], loss:13375.4648
# number:0:epoch [1/10], loss:13874.8691
# number:0:epoch [1/10], loss:13386.0918
# number:0:epoch [1/10], loss:12789.1504
# number:0:epoch [1/10], loss:12599.0264
# number:0:epoch [1/10], loss:12558.2734
# number:0:epoch [1/10], loss:12021.6094
# number:0:epoch [1/10], loss:11573.5820
# number:0:epoch [1/10], loss:11252.3535
# number:0:epoch [1/10], loss:11162.1387
# number:0:epoch [1/10], loss:11068.1211
# number:0:epoch [1/10], loss:10566.8867
# number:0:epoch [1/10], loss:10213.7930
# number:0:epoch [1/10], loss:10653.6924
# number:0:epoch [1/10], loss:10325.6543
# number:0:epoch [1/10], loss:9935.0840
# number:0:epoch [1/10], loss:10278.9395
# number:0:epoch [1/10], loss:9757.9121
# number:0:epoch [1/10], loss:9827.7139
# number:0:epoch [1/10], loss:9861.8105
# number:0:epoch [1/10], loss:10230.9746
# number:0:epoch [1/10], loss:9707.4658
# number:0:epoch [1/10], loss:9534.1152
# number:0:epoch [1/10], loss:9832.4766
# number:0:epoch [1/10], loss:9290.8271
# number:0:epoch [1/10], loss:9273.3428
# number:0:epoch [1/10], loss:9507.8057
# number:0:epoch [1/10], loss:9561.5293
# number:0:epoch [1/10], loss:9457.4268
# number:0:epoch [1/10], loss:9647.6123
# number:0:epoch [1/10], loss:9466.3945
# number:0:epoch [1/10], loss:9535.5908
# number:0:epoch [1/10], loss:9043.9082
# number:0:epoch [1/10], loss:9192.6396
# number:0:epoch [1/10], loss:9097.5537
# number:0:epoch [1/10], loss:8895.0137
# number:0:epoch [1/10], loss:9309.2402
# number:0:epoch [1/10], loss:9028.2959
# number:0:epoch [1/10], loss:9035.7861
# number:0:epoch [1/10], loss:9023.8877
# number:0:epoch [1/10], loss:8893.9688
# number:0:epoch [1/10], loss:8931.2891
# number:0:epoch [1/10], loss:8888.0967
# number:0:epoch [1/10], loss:8792.4248
# number:0:epoch [1/10], loss:9038.1748
# number:0:epoch [1/10], loss:8765.3818
# number:0:epoch [1/10], loss:8714.6064
# number:0:epoch [1/10], loss:8850.1201
# number:0:epoch [1/10], loss:8842.0078
# number:0:epoch [1/10], loss:8726.7285
# number:0:epoch [1/10], loss:8818.1055
# number:0:epoch [1/10], loss:8738.1240
# number:0:epoch [1/10], loss:8670.3594
# number:0:epoch [1/10], loss:8742.1250
# number:0:epoch [1/10], loss:8574.3984
# number:0:epoch [1/10], loss:8926.7139
# number:0:epoch [1/10], loss:8768.1709
# number:0:epoch [1/10], loss:8785.0879
# number:0:epoch [1/10], loss:8554.4580
# number:0:epoch [1/10], loss:8784.8857
# number:0:epoch [1/10], loss:8925.6182
# number:0:epoch [1/10], loss:8669.7783
# number:0:epoch [1/10], loss:8723.9980
# number:0:epoch [1/10], loss:4603.6353
# number:1:epoch [1/10], loss:19655.2715
# number:1:epoch [1/10], loss:11474.9287
# number:1:epoch [1/10], loss:28073.8926
# number:1:epoch [1/10], loss:9878.5273
# number:1:epoch [1/10], loss:9429.5234
# number:1:epoch [1/10], loss:10429.0605
# number:1:epoch [1/10], loss:10763.7998
# number:1:epoch [1/10], loss:10482.0605
# number:1:epoch [1/10], loss:9985.5010
# number:1:epoch [1/10], loss:9165.5254
# number:1:epoch [1/10], loss:8266.9111
# number:1:epoch [1/10], loss:7650.8193
# number:1:epoch [1/10], loss:6964.5938
# number:1:epoch [1/10], loss:7362.6323
# number:1:epoch [1/10], loss:6491.4468
# number:1:epoch [1/10], loss:7188.7607
# number:1:epoch [1/10], loss:6699.2759
# number:1:epoch [1/10], loss:6703.3818
# number:1:epoch [1/10], loss:6109.6411
# number:1:epoch [1/10], loss:6206.7373
# number:1:epoch [1/10], loss:5710.4824
# number:1:epoch [1/10], loss:5860.6670
# number:1:epoch [1/10], loss:5831.4600
# number:1:epoch [1/10], loss:5600.6338
# number:1:epoch [1/10], loss:5328.5020
# number:1:epoch [1/10], loss:5142.6143
# number:1:epoch [1/10], loss:5163.7148
# number:1:epoch [1/10], loss:5197.9922
# number:1:epoch [1/10], loss:5188.5825
# number:1:epoch [1/10], loss:5777.1499
# number:1:epoch [1/10], loss:5277.4453
# number:1:epoch [1/10], loss:5247.6426
# number:1:epoch [1/10], loss:5330.3887
# number:1:epoch [1/10], loss:4899.8252
# number:1:epoch [1/10], loss:5305.7085
# number:1:epoch [1/10], loss:4923.8281
# number:1:epoch [1/10], loss:4822.0547
# number:1:epoch [1/10], loss:5514.2593
# number:1:epoch [1/10], loss:4828.7349
# number:1:epoch [1/10], loss:5039.4678
# number:1:epoch [1/10], loss:4942.0884
# number:1:epoch [1/10], loss:4822.6938
# number:1:epoch [1/10], loss:4898.1885
# number:1:epoch [1/10], loss:4921.9751
# number:1:epoch [1/10], loss:4955.8457
# number:1:epoch [1/10], loss:5008.1260
# number:1:epoch [1/10], loss:4543.8652
# number:1:epoch [1/10], loss:5079.6841
# number:1:epoch [1/10], loss:4983.3945
# number:1:epoch [1/10], loss:4709.8228
# number:1:epoch [1/10], loss:4785.2202
# number:1:epoch [1/10], loss:4983.8994
# number:1:epoch [1/10], loss:4818.3481
# number:1:epoch [1/10], loss:4972.3892
# number:1:epoch [1/10], loss:4731.6597
# number:1:epoch [1/10], loss:4819.5981
# number:1:epoch [1/10], loss:4436.2642
# number:1:epoch [1/10], loss:4980.4238
# number:1:epoch [1/10], loss:4758.1553
# number:1:epoch [1/10], loss:4567.6943
# number:1:epoch [1/10], loss:4612.8877
# number:1:epoch [1/10], loss:4729.8481
# number:1:epoch [1/10], loss:4782.9497
# number:1:epoch [1/10], loss:5099.0864
# number:1:epoch [1/10], loss:4822.8276
# number:1:epoch [1/10], loss:4711.6870
# number:1:epoch [1/10], loss:4823.0430
# number:1:epoch [1/10], loss:4672.2651
# number:1:epoch [1/10], loss:4973.5771
# number:1:epoch [1/10], loss:4829.8462
# number:1:epoch [1/10], loss:4401.7188
# number:1:epoch [1/10], loss:4621.7334
# number:1:epoch [1/10], loss:4783.9487
# number:1:epoch [1/10], loss:4717.2974
# number:1:epoch [1/10], loss:5270.3896
# number:1:epoch [1/10], loss:4655.1484
# number:1:epoch [1/10], loss:4727.7026
# number:1:epoch [1/10], loss:4543.9146
# number:1:epoch [1/10], loss:5121.2500
# number:1:epoch [1/10], loss:4670.5391
# number:1:epoch [1/10], loss:4739.2432
# number:1:epoch [1/10], loss:5137.0317
# number:1:epoch [1/10], loss:4644.2705
# number:1:epoch [1/10], loss:4786.2334
# number:1:epoch [1/10], loss:4933.8447
# number:1:epoch [1/10], loss:4367.4453
# number:1:epoch [1/10], loss:4950.1592
# number:1:epoch [1/10], loss:4699.2114
# number:1:epoch [1/10], loss:4592.0000
# number:1:epoch [1/10], loss:4773.2173
# number:1:epoch [1/10], loss:5406.0664
# number:1:epoch [1/10], loss:4809.0630
# number:1:epoch [1/10], loss:4777.3608
# number:1:epoch [1/10], loss:4718.5991
# number:1:epoch [1/10], loss:4699.2505
# number:1:epoch [1/10], loss:4760.3486
# number:1:epoch [1/10], loss:4483.5000
# number:1:epoch [1/10], loss:4394.3203
# number:1:epoch [1/10], loss:2282.0925
# number:2:epoch [1/10], loss:20951.9258
# number:2:epoch [1/10], loss:17338.6797
# number:2:epoch [1/10], loss:17782.1211
# number:2:epoch [1/10], loss:13880.9941
# number:2:epoch [1/10], loss:14232.9893
# number:2:epoch [1/10], loss:13949.3389
# number:2:epoch [1/10], loss:12982.8379
# number:2:epoch [1/10], loss:13137.2510
# number:2:epoch [1/10], loss:12312.6924
# number:2:epoch [1/10], loss:12432.4189
# number:2:epoch [1/10], loss:12015.0430
# number:2:epoch [1/10], loss:11619.7822
# number:2:epoch [1/10], loss:10678.7568
# number:2:epoch [1/10], loss:10932.5303
# number:2:epoch [1/10], loss:10406.8027
# number:2:epoch [1/10], loss:9734.0420
# number:2:epoch [1/10], loss:9538.9580
# number:2:epoch [1/10], loss:9615.3838
# number:2:epoch [1/10], loss:9374.6533
# number:2:epoch [1/10], loss:9671.0674
# number:2:epoch [1/10], loss:9229.8623
# number:2:epoch [1/10], loss:9381.3721
# number:2:epoch [1/10], loss:9284.4395
# number:2:epoch [1/10], loss:9346.1680
# number:2:epoch [1/10], loss:9518.2852
# number:2:epoch [1/10], loss:9224.2031
# number:2:epoch [1/10], loss:9185.6904
# number:2:epoch [1/10], loss:9218.5449
# number:2:epoch [1/10], loss:8953.4492
# number:2:epoch [1/10], loss:8679.3906
# number:2:epoch [1/10], loss:9302.4951
# number:2:epoch [1/10], loss:9002.5537
# number:2:epoch [1/10], loss:8948.3545
# number:2:epoch [1/10], loss:8768.7393
# number:2:epoch [1/10], loss:8825.8662
# number:2:epoch [1/10], loss:8875.9697
# number:2:epoch [1/10], loss:8667.8125
# number:2:epoch [1/10], loss:8834.7236
# number:2:epoch [1/10], loss:8974.3936
# number:2:epoch [1/10], loss:8792.6094
# number:2:epoch [1/10], loss:8862.0986
# number:2:epoch [1/10], loss:8655.3857
# number:2:epoch [1/10], loss:9091.9678
# number:2:epoch [1/10], loss:8582.5010
# number:2:epoch [1/10], loss:8755.3262
# number:2:epoch [1/10], loss:8926.8682
# number:2:epoch [1/10], loss:8620.1836
# number:2:epoch [1/10], loss:8783.5186
# number:2:epoch [1/10], loss:8841.0830
# number:2:epoch [1/10], loss:8566.7783
# number:2:epoch [1/10], loss:8984.2627
# number:2:epoch [1/10], loss:8596.2666
# number:2:epoch [1/10], loss:8507.1582
# number:2:epoch [1/10], loss:8747.1484
# number:2:epoch [1/10], loss:8745.6553
# number:2:epoch [1/10], loss:8909.4297
# number:2:epoch [1/10], loss:8836.8477
# number:2:epoch [1/10], loss:8861.5850
# number:2:epoch [1/10], loss:8830.5107
# number:2:epoch [1/10], loss:8550.6982
# number:2:epoch [1/10], loss:8688.4414
# number:2:epoch [1/10], loss:8729.4902
# number:2:epoch [1/10], loss:8673.0586
# number:2:epoch [1/10], loss:8678.1523
# number:2:epoch [1/10], loss:8801.5449
# number:2:epoch [1/10], loss:8625.1396
# number:2:epoch [1/10], loss:8316.6416
# number:2:epoch [1/10], loss:8530.3076
# number:2:epoch [1/10], loss:8767.0186
# number:2:epoch [1/10], loss:8711.9619
# number:2:epoch [1/10], loss:8497.1426
# number:2:epoch [1/10], loss:8427.1807
# number:2:epoch [1/10], loss:8807.2705
# number:2:epoch [1/10], loss:8847.3848
# number:2:epoch [1/10], loss:8532.7236
# number:2:epoch [1/10], loss:8501.4697
# number:2:epoch [1/10], loss:8176.6494
# number:2:epoch [1/10], loss:8555.0850
# number:2:epoch [1/10], loss:8308.7656
# number:2:epoch [1/10], loss:8865.6602
# number:2:epoch [1/10], loss:8246.9062
# number:2:epoch [1/10], loss:8479.9307
# number:2:epoch [1/10], loss:8473.1035
# number:2:epoch [1/10], loss:8544.6436
# number:2:epoch [1/10], loss:8339.0547
# number:2:epoch [1/10], loss:8426.4854
# number:2:epoch [1/10], loss:7457.5986
# number:3:epoch [1/10], loss:22340.8477
# number:3:epoch [1/10], loss:16257.1562
# number:3:epoch [1/10], loss:38708.0352
# number:3:epoch [1/10], loss:14813.9102
# number:3:epoch [1/10], loss:15122.3799
# number:3:epoch [1/10], loss:16298.3125
# number:3:epoch [1/10], loss:16804.9004
# number:3:epoch [1/10], loss:16560.3887
# number:3:epoch [1/10], loss:16146.9512
# number:3:epoch [1/10], loss:15938.8740
# number:3:epoch [1/10], loss:14959.6006
# number:3:epoch [1/10], loss:14332.3115
# number:3:epoch [1/10], loss:13121.0820
# number:3:epoch [1/10], loss:13240.9023
# number:3:epoch [1/10], loss:12684.5850
# number:3:epoch [1/10], loss:12103.2764
# number:3:epoch [1/10], loss:12316.3535
# number:3:epoch [1/10], loss:12025.7725
# number:3:epoch [1/10], loss:11835.0059
# number:3:epoch [1/10], loss:11437.1758
# number:3:epoch [1/10], loss:10959.5537
# number:3:epoch [1/10], loss:11984.7578
# number:3:epoch [1/10], loss:11029.2969
# number:3:epoch [1/10], loss:10284.5186
# number:3:epoch [1/10], loss:9673.8330
# number:3:epoch [1/10], loss:9646.0820
# number:3:epoch [1/10], loss:9489.1494
# number:3:epoch [1/10], loss:9573.4951
# number:3:epoch [1/10], loss:9049.7021
# number:3:epoch [1/10], loss:9329.6396
# number:3:epoch [1/10], loss:9155.3584
# number:3:epoch [1/10], loss:9107.2695
# number:3:epoch [1/10], loss:9044.0273
# number:3:epoch [1/10], loss:9096.9492
# number:3:epoch [1/10], loss:8847.8584
# number:3:epoch [1/10], loss:9026.8516
# number:3:epoch [1/10], loss:8865.2725
# number:3:epoch [1/10], loss:9197.5234
# number:3:epoch [1/10], loss:8780.2969
# number:3:epoch [1/10], loss:8846.9912
# number:3:epoch [1/10], loss:8840.6357
# number:3:epoch [1/10], loss:8880.7510
# number:3:epoch [1/10], loss:8529.2568
# number:3:epoch [1/10], loss:8236.3574
# number:3:epoch [1/10], loss:8629.4688
# number:3:epoch [1/10], loss:8545.0068
# number:3:epoch [1/10], loss:8786.0703
# number:3:epoch [1/10], loss:8392.3301
# number:3:epoch [1/10], loss:8553.6709
# number:3:epoch [1/10], loss:8779.6250
# number:3:epoch [1/10], loss:8608.6562
# number:3:epoch [1/10], loss:8433.8555
# number:3:epoch [1/10], loss:8294.2305
# number:3:epoch [1/10], loss:8117.4102
# number:3:epoch [1/10], loss:8503.3086
# number:3:epoch [1/10], loss:8288.2803
# number:3:epoch [1/10], loss:8263.7383
# number:3:epoch [1/10], loss:8228.8096
# number:3:epoch [1/10], loss:8491.7822
# number:3:epoch [1/10], loss:8324.9570
# number:3:epoch [1/10], loss:8264.9180
# number:3:epoch [1/10], loss:8269.7393
# number:3:epoch [1/10], loss:8559.8848
# number:3:epoch [1/10], loss:8185.2256
# number:3:epoch [1/10], loss:8107.1152
# number:3:epoch [1/10], loss:8223.5361
# number:3:epoch [1/10], loss:8344.6240
# number:3:epoch [1/10], loss:8119.7256
# number:3:epoch [1/10], loss:8368.6904
# number:3:epoch [1/10], loss:8275.1367
# number:3:epoch [1/10], loss:8288.3877
# number:3:epoch [1/10], loss:7893.2607
# number:3:epoch [1/10], loss:8052.2979
# number:3:epoch [1/10], loss:8183.6924
# number:3:epoch [1/10], loss:8140.8643
# number:3:epoch [1/10], loss:8265.4678
# number:3:epoch [1/10], loss:8402.1406
# number:3:epoch [1/10], loss:8373.4531
# number:3:epoch [1/10], loss:7988.6055
# number:3:epoch [1/10], loss:7895.5127
# number:3:epoch [1/10], loss:8317.4844
# number:3:epoch [1/10], loss:8170.8691
# number:3:epoch [1/10], loss:8137.3472
# number:3:epoch [1/10], loss:8228.5469
# number:3:epoch [1/10], loss:8414.6211
# number:3:epoch [1/10], loss:8099.6675
# number:3:epoch [1/10], loss:8083.2627
# number:3:epoch [1/10], loss:8118.3521
# number:3:epoch [1/10], loss:7915.8848
# number:3:epoch [1/10], loss:5222.9829
# number:4:epoch [1/10], loss:17729.9883
# number:4:epoch [1/10], loss:15187.3730
# number:4:epoch [1/10], loss:15270.8887
# number:4:epoch [1/10], loss:11804.7969
# number:4:epoch [1/10], loss:7463.4844
# number:4:epoch [1/10], loss:7525.9751
# number:4:epoch [1/10], loss:7242.9238
# number:4:epoch [1/10], loss:7393.9736
# number:4:epoch [1/10], loss:7253.0957
# number:4:epoch [1/10], loss:7466.6582
# number:4:epoch [1/10], loss:7316.4561
# number:4:epoch [1/10], loss:7050.7119
# number:4:epoch [1/10], loss:7407.0757
# number:4:epoch [1/10], loss:7428.1152
# number:4:epoch [1/10], loss:7240.4751
# number:4:epoch [1/10], loss:2034.1655
# number:5:epoch [1/10], loss:22324.5762
# number:5:epoch [1/10], loss:15153.2373
# number:5:epoch [1/10], loss:15866.3301
# number:5:epoch [1/10], loss:14496.4912
# number:5:epoch [1/10], loss:12669.6113
# number:5:epoch [1/10], loss:13377.0645
# number:5:epoch [1/10], loss:12355.5654
# number:5:epoch [1/10], loss:11954.6484
# number:5:epoch [1/10], loss:11071.0596
# number:5:epoch [1/10], loss:10711.3945
# number:5:epoch [1/10], loss:9995.4131
# number:5:epoch [1/10], loss:9958.1133
# number:5:epoch [1/10], loss:8912.7227
# number:5:epoch [1/10], loss:8958.4033
# number:5:epoch [1/10], loss:8871.9043
# number:5:epoch [1/10], loss:8701.5186
# number:5:epoch [1/10], loss:9196.0615
# number:5:epoch [1/10], loss:9050.8711
# number:5:epoch [1/10], loss:8597.1133
# number:5:epoch [1/10], loss:8943.8457
# number:5:epoch [1/10], loss:8467.4453
# number:5:epoch [1/10], loss:8592.7441
# number:5:epoch [1/10], loss:9016.6162
# number:5:epoch [1/10], loss:8497.3164
# number:5:epoch [1/10], loss:8215.7266
# number:5:epoch [1/10], loss:8293.6016
# number:5:epoch [1/10], loss:8647.3145
# number:5:epoch [1/10], loss:8661.5576
# number:5:epoch [1/10], loss:8327.3359
# number:5:epoch [1/10], loss:8025.6709
# number:5:epoch [1/10], loss:8306.8340
# number:5:epoch [1/10], loss:8575.0225
# number:5:epoch [1/10], loss:8368.8604
# number:5:epoch [1/10], loss:8115.4575
# number:5:epoch [1/10], loss:8339.5400
# number:5:epoch [1/10], loss:8382.9561
# number:5:epoch [1/10], loss:7895.3232
# number:5:epoch [1/10], loss:8457.1230
# number:5:epoch [1/10], loss:8256.9902
# number:5:epoch [1/10], loss:8109.7480
# number:5:epoch [1/10], loss:8106.1392
# number:5:epoch [1/10], loss:8137.4551
# number:5:epoch [1/10], loss:8085.7837
# number:5:epoch [1/10], loss:8605.5322
# number:5:epoch [1/10], loss:8475.0273
# number:5:epoch [1/10], loss:8310.2695
# number:5:epoch [1/10], loss:7840.5615
# number:5:epoch [1/10], loss:7865.8833
# number:5:epoch [1/10], loss:8238.6230
# number:5:epoch [1/10], loss:8240.1680
# number:5:epoch [1/10], loss:8020.7764
# number:5:epoch [1/10], loss:7927.0264
# number:5:epoch [1/10], loss:8102.7407
# number:5:epoch [1/10], loss:8051.3354
# number:5:epoch [1/10], loss:8094.7319
# number:5:epoch [1/10], loss:7959.0762
# number:5:epoch [1/10], loss:7951.3379
# number:5:epoch [1/10], loss:7856.4927
# number:5:epoch [1/10], loss:8136.0264
# number:5:epoch [1/10], loss:8229.4111
# number:5:epoch [1/10], loss:7978.8164
# number:5:epoch [1/10], loss:7850.9536
# number:5:epoch [1/10], loss:8149.9473
# number:5:epoch [1/10], loss:7944.0376
# number:5:epoch [1/10], loss:7924.6416
# number:5:epoch [1/10], loss:8153.7246
# number:5:epoch [1/10], loss:7769.6758
# number:5:epoch [1/10], loss:8081.5215
# number:5:epoch [1/10], loss:7743.3364
# number:5:epoch [1/10], loss:7728.5151
# number:5:epoch [1/10], loss:7933.2119
# number:5:epoch [1/10], loss:8121.3774
# number:5:epoch [1/10], loss:8104.5312
# number:5:epoch [1/10], loss:7872.0376
# number:5:epoch [1/10], loss:8362.5732
# number:5:epoch [1/10], loss:7901.9033
# number:5:epoch [1/10], loss:7803.8857
# number:5:epoch [1/10], loss:8193.1865
# number:5:epoch [1/10], loss:3753.3228
# number:6:epoch [1/10], loss:20369.4023
# number:6:epoch [1/10], loss:16881.6797
# number:6:epoch [1/10], loss:16850.3457
# number:6:epoch [1/10], loss:12351.2295
# number:6:epoch [1/10], loss:12495.1611
# number:6:epoch [1/10], loss:12411.6279
# number:6:epoch [1/10], loss:11795.4814
# number:6:epoch [1/10], loss:11173.7109
# number:6:epoch [1/10], loss:10945.6436
# number:6:epoch [1/10], loss:10833.5186
# number:6:epoch [1/10], loss:9549.4463
# number:6:epoch [1/10], loss:9706.7793
# number:6:epoch [1/10], loss:8970.0908
# number:6:epoch [1/10], loss:8433.1797
# number:6:epoch [1/10], loss:8440.9639
# number:6:epoch [1/10], loss:8455.7793
# number:6:epoch [1/10], loss:8123.5366
# number:6:epoch [1/10], loss:8577.2930
# number:6:epoch [1/10], loss:8199.8496
# number:6:epoch [1/10], loss:8372.6455
# number:6:epoch [1/10], loss:8470.9355
# number:6:epoch [1/10], loss:8462.8789
# number:6:epoch [1/10], loss:8248.4385
# number:6:epoch [1/10], loss:8175.1011
# number:6:epoch [1/10], loss:7991.8022
# number:6:epoch [1/10], loss:7829.7251
# number:6:epoch [1/10], loss:7777.5186
# number:6:epoch [1/10], loss:7819.9092
# number:6:epoch [1/10], loss:8022.3340
# number:6:epoch [1/10], loss:7870.3623
# number:6:epoch [1/10], loss:7609.1382
# number:6:epoch [1/10], loss:7468.3477
# number:6:epoch [1/10], loss:7344.5405
# number:6:epoch [1/10], loss:7647.6797
# number:6:epoch [1/10], loss:7613.3867
# number:6:epoch [1/10], loss:7762.3765
# number:6:epoch [1/10], loss:8131.4863
# number:6:epoch [1/10], loss:7575.2803
# number:6:epoch [1/10], loss:7654.5312
# number:6:epoch [1/10], loss:7788.7920
# number:6:epoch [1/10], loss:7776.7720
# number:6:epoch [1/10], loss:7547.4478
# number:6:epoch [1/10], loss:7667.6626
# number:6:epoch [1/10], loss:7764.1045
# number:6:epoch [1/10], loss:8247.9834
# number:6:epoch [1/10], loss:7627.8320
# number:6:epoch [1/10], loss:7776.4253
# number:6:epoch [1/10], loss:7610.3423
# number:6:epoch [1/10], loss:7604.5195
# number:6:epoch [1/10], loss:7773.8071
# number:6:epoch [1/10], loss:7541.5776
# number:6:epoch [1/10], loss:7784.7422
# number:6:epoch [1/10], loss:7501.5400
# number:6:epoch [1/10], loss:7484.3228
# number:6:epoch [1/10], loss:7666.3145
# number:6:epoch [1/10], loss:7867.9668
# number:6:epoch [1/10], loss:7353.8442
# number:6:epoch [1/10], loss:7663.9297
# number:6:epoch [1/10], loss:7941.6538
# number:6:epoch [1/10], loss:7760.3042
# number:6:epoch [1/10], loss:7069.0723
# number:6:epoch [1/10], loss:7358.1294
# number:6:epoch [1/10], loss:7278.4976
# number:6:epoch [1/10], loss:7548.9111
# number:6:epoch [1/10], loss:7344.8662
# number:6:epoch [1/10], loss:7447.1821
# number:6:epoch [1/10], loss:7415.5640
# number:6:epoch [1/10], loss:7140.5811
# number:6:epoch [1/10], loss:7151.7866
# number:6:epoch [1/10], loss:7331.0508
# number:6:epoch [1/10], loss:7302.2295
# number:6:epoch [1/10], loss:7333.6250
# number:6:epoch [1/10], loss:7124.3535
# number:6:epoch [1/10], loss:7114.5625
# number:6:epoch [1/10], loss:7407.3257
# number:6:epoch [1/10], loss:7205.4380
# number:6:epoch [1/10], loss:7161.2842
# number:6:epoch [1/10], loss:7249.8765
# number:6:epoch [1/10], loss:6884.1040
# number:6:epoch [1/10], loss:6996.2559
# number:6:epoch [1/10], loss:7229.2407
# number:6:epoch [1/10], loss:7121.6426
# number:6:epoch [1/10], loss:6989.1499
# number:6:epoch [1/10], loss:7544.5449
# number:6:epoch [1/10], loss:6997.8960
# number:6:epoch [1/10], loss:6989.3711
# number:6:epoch [1/10], loss:3942.0266
# number:7:epoch [1/10], loss:22260.5605
# number:7:epoch [1/10], loss:18464.5488
# number:7:epoch [1/10], loss:15824.0068
# number:7:epoch [1/10], loss:12622.1123
# number:7:epoch [1/10], loss:13319.4854
# number:7:epoch [1/10], loss:10996.1729
# number:7:epoch [1/10], loss:10461.3301
# number:7:epoch [1/10], loss:10306.1104
# number:7:epoch [1/10], loss:9753.5293
# number:7:epoch [1/10], loss:9827.0195
# number:7:epoch [1/10], loss:9485.8896
# number:7:epoch [1/10], loss:8774.3018
# number:7:epoch [1/10], loss:8042.7520
# number:7:epoch [1/10], loss:8342.6846
# number:7:epoch [1/10], loss:7795.3188
# number:7:epoch [1/10], loss:8260.1855
# number:7:epoch [1/10], loss:7903.9717
# number:7:epoch [1/10], loss:7935.4829
# number:7:epoch [1/10], loss:7898.0210
# number:7:epoch [1/10], loss:7783.1719
# number:7:epoch [1/10], loss:7748.4985
# number:7:epoch [1/10], loss:7663.5864
# number:7:epoch [1/10], loss:7880.4956
# number:7:epoch [1/10], loss:7629.1641
# number:7:epoch [1/10], loss:7520.4463
# number:7:epoch [1/10], loss:7806.2539
# number:7:epoch [1/10], loss:7234.0771
# number:7:epoch [1/10], loss:7498.9814
# number:7:epoch [1/10], loss:7542.9004
# number:8:epoch [1/10], loss:10985.4717
# number:8:epoch [1/10], loss:10180.6777
# number:8:epoch [1/10], loss:9712.3408
# number:8:epoch [1/10], loss:10015.4756
# number:8:epoch [1/10], loss:9467.5977
# number:8:epoch [1/10], loss:9387.1436
# number:8:epoch [1/10], loss:9022.3447
# number:8:epoch [1/10], loss:9062.4062
# number:8:epoch [1/10], loss:9264.5254
# number:8:epoch [1/10], loss:8679.6045
# number:8:epoch [1/10], loss:8508.1406
# number:8:epoch [1/10], loss:8997.5762
# number:8:epoch [1/10], loss:8557.4551
# number:8:epoch [1/10], loss:8384.3203
# number:8:epoch [1/10], loss:8699.6777
# number:8:epoch [1/10], loss:8599.1035
# number:8:epoch [1/10], loss:8380.0576
# number:8:epoch [1/10], loss:8739.8467
# number:8:epoch [1/10], loss:8473.6318
# number:8:epoch [1/10], loss:8573.8457
# number:8:epoch [1/10], loss:8474.7051
# number:8:epoch [1/10], loss:8056.8721
# number:8:epoch [1/10], loss:8412.7266
# number:8:epoch [1/10], loss:8371.9736
# number:8:epoch [1/10], loss:8745.9775
# number:8:epoch [1/10], loss:8375.3818
# number:8:epoch [1/10], loss:8518.8096
# number:8:epoch [1/10], loss:8225.7598
# number:8:epoch [1/10], loss:7961.5332
# number:8:epoch [1/10], loss:8127.2378
# number:8:epoch [1/10], loss:8358.4473
# number:8:epoch [1/10], loss:7987.2100
# number:8:epoch [1/10], loss:8550.8936
# number:8:epoch [1/10], loss:8583.4551
# number:8:epoch [1/10], loss:8458.7578
# number:8:epoch [1/10], loss:8198.4971
# number:8:epoch [1/10], loss:8151.0728
# number:8:epoch [1/10], loss:8304.9717
# number:8:epoch [1/10], loss:8253.8662
# number:8:epoch [1/10], loss:8152.2856
# number:8:epoch [1/10], loss:8467.5801
# number:8:epoch [1/10], loss:8036.5923
# number:8:epoch [1/10], loss:7994.6611
# number:8:epoch [1/10], loss:8279.9492
# number:8:epoch [1/10], loss:7948.0913
# number:8:epoch [1/10], loss:8062.4644
# number:8:epoch [1/10], loss:8404.7080
# number:8:epoch [1/10], loss:8058.2686
# number:8:epoch [1/10], loss:8126.6777
# number:8:epoch [1/10], loss:8337.9121
# number:8:epoch [1/10], loss:8244.2842
# number:8:epoch [1/10], loss:8209.1084
# number:8:epoch [1/10], loss:7947.9287
# number:8:epoch [1/10], loss:8398.3262
# number:8:epoch [1/10], loss:8203.8779
# number:8:epoch [1/10], loss:8077.8149
# number:8:epoch [1/10], loss:8486.1104
# number:8:epoch [1/10], loss:8396.8174
# number:8:epoch [1/10], loss:8123.8394
# number:8:epoch [1/10], loss:8291.0146
# number:8:epoch [1/10], loss:8499.1348
# number:8:epoch [1/10], loss:7862.0557
# number:8:epoch [1/10], loss:8313.3447
# number:8:epoch [1/10], loss:8367.5312
# number:8:epoch [1/10], loss:7755.8413
# number:8:epoch [1/10], loss:8370.8184
# number:8:epoch [1/10], loss:8158.9785
# number:8:epoch [1/10], loss:7879.0059
# number:8:epoch [1/10], loss:7847.3809
# number:0:epoch [2/10], loss:8416.5088
# number:0:epoch [2/10], loss:8443.0195
# number:0:epoch [2/10], loss:8556.2158
# number:0:epoch [2/10], loss:8492.6230
# number:0:epoch [2/10], loss:8600.8066
# number:0:epoch [2/10], loss:8487.3291
# number:0:epoch [2/10], loss:8343.6348
# number:0:epoch [2/10], loss:8432.1357
# number:0:epoch [2/10], loss:8265.8652
# number:0:epoch [2/10], loss:8576.7637
# number:0:epoch [2/10], loss:8502.4150
# number:0:epoch [2/10], loss:8507.3896
# number:0:epoch [2/10], loss:8324.9092
# number:0:epoch [2/10], loss:8398.3340
# number:0:epoch [2/10], loss:8484.4473
# number:0:epoch [2/10], loss:8373.2568
# number:0:epoch [2/10], loss:8526.8525
# number:0:epoch [2/10], loss:8293.6924
# number:0:epoch [2/10], loss:8563.6689
# number:0:epoch [2/10], loss:8343.3184
# number:0:epoch [2/10], loss:8398.4385
# number:0:epoch [2/10], loss:8356.4805
# number:0:epoch [2/10], loss:8447.4482
# number:0:epoch [2/10], loss:8551.7266
# number:0:epoch [2/10], loss:8512.1455
# number:0:epoch [2/10], loss:8605.7500
# number:0:epoch [2/10], loss:8346.9941
# number:0:epoch [2/10], loss:8512.4482
# number:0:epoch [2/10], loss:8376.9600
# number:0:epoch [2/10], loss:8557.4316
# number:0:epoch [2/10], loss:8511.0928
# number:0:epoch [2/10], loss:8619.8154
# number:0:epoch [2/10], loss:8566.4873
# number:0:epoch [2/10], loss:8161.4795
# number:0:epoch [2/10], loss:8391.2568
# number:0:epoch [2/10], loss:8762.9648
# number:0:epoch [2/10], loss:8460.7373
# number:0:epoch [2/10], loss:8332.0615
# number:0:epoch [2/10], loss:8343.4248
# number:0:epoch [2/10], loss:8227.7275
# number:0:epoch [2/10], loss:8613.4082
# number:0:epoch [2/10], loss:8508.1338
# number:0:epoch [2/10], loss:8459.5273
# number:0:epoch [2/10], loss:8165.8779
# number:0:epoch [2/10], loss:8431.6680
# number:0:epoch [2/10], loss:8579.4814
# number:0:epoch [2/10], loss:4408.8413
# number:1:epoch [2/10], loss:4909.4072
# number:1:epoch [2/10], loss:4574.0381
# number:1:epoch [2/10], loss:4565.8135
# number:1:epoch [2/10], loss:4782.7866
# number:1:epoch [2/10], loss:4578.0474
# number:1:epoch [2/10], loss:4606.8970
# number:1:epoch [2/10], loss:4729.1704
# number:1:epoch [2/10], loss:4324.7280
# number:1:epoch [2/10], loss:4789.2603
# number:1:epoch [2/10], loss:4303.6987
# number:1:epoch [2/10], loss:4660.2192
# number:1:epoch [2/10], loss:4575.2065
# number:1:epoch [2/10], loss:4416.1035
# number:1:epoch [2/10], loss:4204.0151
# number:1:epoch [2/10], loss:4730.9458
# number:1:epoch [2/10], loss:4471.4409
# number:1:epoch [2/10], loss:4393.9360
# number:1:epoch [2/10], loss:4594.0957
# number:1:epoch [2/10], loss:4643.7646
# number:1:epoch [2/10], loss:4182.6963
# number:1:epoch [2/10], loss:4317.5742
# number:1:epoch [2/10], loss:4380.0273
# number:1:epoch [2/10], loss:4417.4033
# number:1:epoch [2/10], loss:4446.3413
# number:1:epoch [2/10], loss:4750.6206
# number:1:epoch [2/10], loss:4323.6094
# number:1:epoch [2/10], loss:4440.4766
# number:1:epoch [2/10], loss:4394.2700
# number:1:epoch [2/10], loss:4289.1401
# number:1:epoch [2/10], loss:4326.2583
# number:1:epoch [2/10], loss:4113.6675
# number:1:epoch [2/10], loss:4121.8574
# number:1:epoch [2/10], loss:4232.1587
# number:1:epoch [2/10], loss:4377.3389
# number:1:epoch [2/10], loss:4016.4880
# number:1:epoch [2/10], loss:4054.6694
# number:1:epoch [2/10], loss:4146.3296
# number:1:epoch [2/10], loss:4057.3403
# number:1:epoch [2/10], loss:4083.1243
# number:1:epoch [2/10], loss:3922.3472
# number:1:epoch [2/10], loss:3893.8555
# number:1:epoch [2/10], loss:4103.3423
# number:1:epoch [2/10], loss:3733.1841
# number:1:epoch [2/10], loss:3701.2861
# number:1:epoch [2/10], loss:4153.6704
# number:1:epoch [2/10], loss:4059.2991
# number:1:epoch [2/10], loss:3770.0420
# number:1:epoch [2/10], loss:3626.2263
# number:1:epoch [2/10], loss:3860.9353
# number:1:epoch [2/10], loss:3973.4841
# number:1:epoch [2/10], loss:4054.1428
# number:1:epoch [2/10], loss:3741.4009
# number:1:epoch [2/10], loss:3722.2170
# number:1:epoch [2/10], loss:3800.1511
# number:1:epoch [2/10], loss:3670.4248
# number:1:epoch [2/10], loss:3673.8850
# number:1:epoch [2/10], loss:3948.9739
# number:1:epoch [2/10], loss:3784.9666
# number:1:epoch [2/10], loss:3713.0603
# number:1:epoch [2/10], loss:3621.1313
# number:1:epoch [2/10], loss:3762.9668
# number:1:epoch [2/10], loss:3601.6672
# number:1:epoch [2/10], loss:3698.6277
# number:1:epoch [2/10], loss:3637.3906
# number:1:epoch [2/10], loss:3409.0999
# number:1:epoch [2/10], loss:3704.1865
# number:1:epoch [2/10], loss:3544.6345
# number:1:epoch [2/10], loss:4111.9204
# number:1:epoch [2/10], loss:3759.8372
# number:1:epoch [2/10], loss:3726.5173
# number:1:epoch [2/10], loss:4092.5867
# number:1:epoch [2/10], loss:3516.5569
# number:1:epoch [2/10], loss:3660.5918
# number:1:epoch [2/10], loss:3504.7654
# number:1:epoch [2/10], loss:3671.5071
# number:1:epoch [2/10], loss:3338.4397
# number:1:epoch [2/10], loss:3665.7913
# number:1:epoch [2/10], loss:4065.7310
# number:1:epoch [2/10], loss:3652.6191
# number:1:epoch [2/10], loss:3775.0864
# number:1:epoch [2/10], loss:3644.1653
# number:1:epoch [2/10], loss:3642.3833
# number:1:epoch [2/10], loss:3657.8328
# number:1:epoch [2/10], loss:3499.7205
# number:1:epoch [2/10], loss:3419.0979
# number:1:epoch [2/10], loss:3737.5261
# number:1:epoch [2/10], loss:3469.6448
# number:1:epoch [2/10], loss:3937.7466
# number:1:epoch [2/10], loss:3834.5493
# number:1:epoch [2/10], loss:3419.1921
# number:1:epoch [2/10], loss:3543.7847
# number:5:epoch [10/10], loss:4107.5791
# number:5:epoch [10/10], loss:4306.2974
# number:5:epoch [10/10], loss:4160.0415
# number:5:epoch [10/10], loss:4229.5537
# number:5:epoch [10/10], loss:4148.0151
# number:5:epoch [10/10], loss:4209.3916
# number:5:epoch [10/10], loss:4345.9854
# number:5:epoch [10/10], loss:4012.6692
# number:5:epoch [10/10], loss:4155.5864
# number:5:epoch [10/10], loss:4279.4019
# number:5:epoch [10/10], loss:4311.9409
# number:5:epoch [10/10], loss:4095.1914
# number:5:epoch [10/10], loss:4308.3784
# number:5:epoch [10/10], loss:4135.7954
# number:5:epoch [10/10], loss:4043.8198
# number:5:epoch [10/10], loss:4179.9814
# number:5:epoch [10/10], loss:4297.0771
# number:5:epoch [10/10], loss:4249.4780
# number:5:epoch [10/10], loss:4340.7251
# number:5:epoch [10/10], loss:4294.4390
# number:5:epoch [10/10], loss:4058.6296
# number:5:epoch [10/10], loss:4151.9199
# number:5:epoch [10/10], loss:4165.7427
# number:5:epoch [10/10], loss:4233.1670
# number:5:epoch [10/10], loss:4184.5190
# number:5:epoch [10/10], loss:4261.3701
# number:5:epoch [10/10], loss:4246.2910
# number:5:epoch [10/10], loss:4225.3345
# number:5:epoch [10/10], loss:4119.6470
# number:5:epoch [10/10], loss:4132.1973
# number:5:epoch [10/10], loss:4165.3887
# number:5:epoch [10/10], loss:4082.0747
# number:5:epoch [10/10], loss:4033.8254
# number:5:epoch [10/10], loss:4135.7520
# number:5:epoch [10/10], loss:4168.3667
# number:5:epoch [10/10], loss:4202.9424
# number:5:epoch [10/10], loss:4210.0430
# number:5:epoch [10/10], loss:4144.1177
# number:5:epoch [10/10], loss:4219.2734
# number:5:epoch [10/10], loss:4191.3677
# number:5:epoch [10/10], loss:4299.3408
# number:5:epoch [10/10], loss:4240.2710
# number:5:epoch [10/10], loss:4323.7642
# number:5:epoch [10/10], loss:4201.5703
# number:5:epoch [10/10], loss:4199.0386
# number:5:epoch [10/10], loss:4213.8965
# number:5:epoch [10/10], loss:4137.7549
# number:5:epoch [10/10], loss:4234.1382
# number:5:epoch [10/10], loss:4259.6045
# number:5:epoch [10/10], loss:4244.0981
# number:5:epoch [10/10], loss:4274.7607
# number:5:epoch [10/10], loss:4079.4180
# number:5:epoch [10/10], loss:1916.3254
# number:6:epoch [10/10], loss:4017.1174
# number:6:epoch [10/10], loss:4108.3555
# number:6:epoch [10/10], loss:3715.9746
# number:6:epoch [10/10], loss:4140.8179
# number:6:epoch [10/10], loss:3870.7236
# number:6:epoch [10/10], loss:3908.0701
# number:6:epoch [10/10], loss:4015.8911
# number:6:epoch [10/10], loss:3861.8711
# number:6:epoch [10/10], loss:3985.3877
# number:6:epoch [10/10], loss:3920.8220
# number:6:epoch [10/10], loss:3898.7083
# number:6:epoch [10/10], loss:4067.0247
# number:6:epoch [10/10], loss:3793.9990
# number:6:epoch [10/10], loss:4074.0474
# number:6:epoch [10/10], loss:3998.7649
# number:6:epoch [10/10], loss:3885.9595
# number:9:epoch [10/10], loss:3832.6826
# number:9:epoch [10/10], loss:3929.1138
# number:9:epoch [10/10], loss:3812.2917
# number:9:epoch [10/10], loss:3919.8098
# number:9:epoch [10/10], loss:3880.3308
# number:9:epoch [10/10], loss:3777.0767
# number:9:epoch [10/10], loss:3613.4507
# number:9:epoch [10/10], loss:3899.8164
# number:9:epoch [10/10], loss:3716.3518
# number:9:epoch [10/10], loss:3691.8418
# number:9:epoch [10/10], loss:3931.8552
# number:9:epoch [10/10], loss:3971.8208
# number:9:epoch [10/10], loss:3873.2595
# number:9:epoch [10/10], loss:3834.1614
# number:9:epoch [10/10], loss:3908.4814
# number:9:epoch [10/10], loss:3765.6521
# number:9:epoch [10/10], loss:3821.2788
# number:9:epoch [10/10], loss:3787.5374
# number:9:epoch [10/10], loss:3807.6426
# number:9:epoch [10/10], loss:3858.7959
# number:9:epoch [10/10], loss:3894.9443
# number:9:epoch [10/10], loss:3831.4375
# number:9:epoch [10/10], loss:3748.2744
# number:9:epoch [10/10], loss:3848.3083
# number:9:epoch [10/10], loss:3768.0747
# number:9:epoch [10/10], loss:3721.1597
# number:9:epoch [10/10], loss:4118.1406
# number:9:epoch [10/10], loss:3892.9053
# number:9:epoch [10/10], loss:3904.1509
# number:9:epoch [10/10], loss:3802.5208
# number:9:epoch [10/10], loss:3943.7844
# number:9:epoch [10/10], loss:3862.3748
# number:9:epoch [10/10], loss:3879.0845
# number:9:epoch [10/10], loss:4079.0093
# number:9:epoch [10/10], loss:3838.4858
# number:9:epoch [10/10], loss:3874.8276
# number:9:epoch [10/10], loss:3835.6365
# number:9:epoch [10/10], loss:3980.0195
# number:9:epoch [10/10], loss:4039.6719
# number:9:epoch [10/10], loss:3967.5378
# number:9:epoch [10/10], loss:4042.7292
# number:9:epoch [10/10], loss:3820.2954
# number:9:epoch [10/10], loss:3798.6409
# number:9:epoch [10/10], loss:3740.4258
# number:9:epoch [10/10], loss:3774.3777
# number:9:epoch [10/10], loss:3688.4106
# number:9:epoch [10/10], loss:3710.4312
# number:9:epoch [10/10], loss:3775.3650
# number:9:epoch [10/10], loss:3853.5977
# number:9:epoch [10/10], loss:3760.8643
# number:9:epoch [10/10], loss:3898.3508
# number:9:epoch [10/10], loss:3838.4204
# number:9:epoch [10/10], loss:3751.0063
# number:9:epoch [10/10], loss:3808.7476
# number:9:epoch [10/10], loss:3819.8928
# number:9:epoch [10/10], loss:3802.6145
# number:9:epoch [10/10], loss:3992.3506
# number:9:epoch [10/10], loss:3704.3076
# number:9:epoch [10/10], loss:3782.3843
# number:9:epoch [10/10], loss:2886.9319

# %%
test()
# Out:
# c:\Users\22732\.conda\envs\AIwork\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# OOD Detection: Accuracy: 0.95, Precision: 1.00, Recall: 0.95, F1-score: 0.97
# In MNIST:Accuracy: 0.90, Precision: 0.91, Recall: 0.90, F1-score: 0.90

# %%
model_dict = {f'VAE_digit_{i}': vae.state_dict() for i, vae in enumerate(vaes)}
torch.save(model_dict, 'VAEs.pth')
