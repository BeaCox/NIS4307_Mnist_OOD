# %%
import torch
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms
from torch import nn, optim
from torch.nn import functional as F
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np
from tqdm import tqdm

# %%
# 超参数定义
num_epochs = 30
batch_size = 64
learning_rate = 8e-3
thresholds_percent = 0.8
KLD_weight = 0.6
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# 数据增强
transform = transforms.Compose([
    transforms.RandomRotation(25),
    transforms.ToTensor(),
])
transform2 = transforms.Compose([
    transforms.ToTensor(),
])

# 加载全部数据
mnist_data = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_data2 = datasets.MNIST(root='./data', train=False, download=True, transform=transform2)
# 合并数据集
mnist_data = torch.utils.data.ConcatDataset([mnist_data, mnist_data2])
# 获取数据集的大小
total_size = len(mnist_data)
# 计算训练数据集的大小（80%）
train_size = int(total_size * 0.8)
# 计算测试数据集的大小（20%）
test_size = total_size - train_size
# 分割数据集
train_data, test_data = torch.utils.data.random_split(mnist_data, [train_size, test_size])

# 对于每个数字，创建一个数据加载器
digit_train_loaders = [DataLoader(Subset(train_data, 
                       [idx for idx, (_, target) in enumerate(train_data) if target == i]),
                       batch_size=batch_size, shuffle=True) for i in range(10)]

# 对于每个数字，创建一个测试数据加载器
digit_test_loaders = [DataLoader(Subset(test_data, 
                       [idx for idx, (_, target) in enumerate(test_data) if target == i]),
                       batch_size=batch_size, shuffle=True) for i in range(10)]

# %%
class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()
        self.fc1 = nn.Linear(784, 500)  # 增大第一层的输出大小
        self.fc21 = nn.Linear(500, 30)  # 增大第二层的输出大小
        self.fc22 = nn.Linear(500, 30)  # 增大第二层的输出大小
        self.fc3 = nn.Linear(30, 500)   # 增大第三层的输入大小
        self.fc4 = nn.Linear(500, 784)  # 增大第四层的输入大小

    def encode(self, x):
        h1 = F.relu(self.fc1(x))
        return self.fc21(h1), self.fc22(h1) 

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std) 
        return mu + eps * std

    def decode(self, z):
        h3 = F.relu(self.fc3(z))
        return torch.sigmoid(self.fc4(h3))

    def forward(self, x):
        mu, logvar = self.encode(x.view(-1, 784))
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar

# %%
# 用于存储每个数字对应的模型
vaes = [VAE().to(device) for _ in range(10)]
optimizers = [optim.Adamax(vae.parameters(), lr=learning_rate) for vae in vaes]

# %%
def loss_function(recon_x, x, mu, logvar):
    BCE = F.binary_cross_entropy(recon_x, x.view(-1, 784), reduction='sum')
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return (1-KLD_weight)*BCE + KLD_weight*KLD
# 训练模型
def train():
    for epoch in range(num_epochs):
        for i in range(10):
            for data in digit_train_loaders[i]:
                img, _ = data
                img = img.to(device)
                img = img.view(img.size(0), -1)
                recon_batch, mu, logvar = vaes[i](img)
                loss = loss_function(recon_batch, img, mu, logvar)
                print('number:{}:epoch [{}/{}], loss:{:.4f}'.format(i,epoch + 1, num_epochs, loss.item()))
                optimizers[i].zero_grad()
                loss.backward()
                optimizers[i].step()

# 计算重构误差
def compute_reconstruction_error(data, model):
    with torch.no_grad():
        recon_data, _, _ = model(data)
        recon_error = ((recon_data - data.view(-1, 784))**2).sum(dim=1)
        return recon_error.cpu().numpy()

# %%
def test():
    # 加载FashionMNIST测试数据作为OOD样本
    fashion_mnist_data = datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)
    fashion_mnist_loader = DataLoader(fashion_mnist_data, batch_size=batch_size, shuffle=False)

    # 对于每个测试样本，计算其对于每个模型的重构误差
    test_errors = []
    # 计算FashionMNIST样本在每个模型上的重构误差
    fashion_errors = []
    with torch.no_grad():
        for data, _ in fashion_mnist_loader:
            img = data.to(device)
            img = img.view(img.size(0), -1)
            errors = np.stack([compute_reconstruction_error(img, vae) for vae in vaes], axis=-1)
            fashion_errors.extend(errors)
    fashion_errors = np.array(fashion_errors)
    
    # 计算阈值，设置为训练集上的thresholds_percent重构误差百分位数
    thresholds = [np.percentile([compute_reconstruction_error(data, vaes[i]).max() 
                 for data, _ in digit_train_loaders[i]], thresholds_percent) for i in range(10)]
    # 对FashionMNIST样本进行分类
    fashion_pred = np.argmin(fashion_errors, axis=1)
    # 如果重构误差大于阈值，则判断为OOD
    fashion_pred = [pred if error[pred] <= thresholds[pred] else 10 for pred, error in zip(fashion_pred, fashion_errors)]
    # 计算OOD检测的准确率，精确度，召回率和F1分数
    fashion_true = [10] * len(fashion_pred) # 10表示OOD
    accuracy = accuracy_score(fashion_true, fashion_pred)
    precision = precision_score(fashion_true, fashion_pred, average='weighted')
    recall = recall_score(fashion_true, fashion_pred, average='weighted')
    f1 = f1_score(fashion_true, fashion_pred, average='weighted')
    print(f"OOD Detection: Accuracy: {accuracy:.2f}, Precision: {precision:.2f}, Recall: {recall:.2f}, F1-score: {f1:.2f}")
    
    y_true = []
    test_errors = []
    with torch.no_grad():
        for i in range(10):
            for data, targets in digit_test_loaders[i]:
                img = data.to(device)
                img = img.view(img.size(0), -1)
                errors = np.stack([compute_reconstruction_error(img, vae) for vae in vaes], axis=-1)
                test_errors.extend(errors)
                y_true.extend(targets.numpy())
    test_errors = np.array(test_errors)

    # 对于每个测试样本，将其分类为重构误差最小的类别
    y_pred = np.argmin(test_errors, axis=1)
    
    # 计算accuracy，precision，recall和F1-score
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    f1 = f1_score(y_true, y_pred, average='weighted')

    print(f"In MNIST:Accuracy: {accuracy:.2f}, Precision: {precision:.2f}, Recall: {recall:.2f}, F1-score: {f1:.2f}")

# %%
train()
# Out:
# number:0:epoch [1/30], loss:14029.3740
# number:0:epoch [1/30], loss:10665.4492
# number:0:epoch [1/30], loss:7428.0913
# number:0:epoch [1/30], loss:6539.5601
# number:0:epoch [1/30], loss:5979.0430
# number:0:epoch [1/30], loss:5992.2544
# number:0:epoch [1/30], loss:5974.5449
# number:0:epoch [1/30], loss:5732.2817
# number:0:epoch [1/30], loss:5729.4268
# number:0:epoch [1/30], loss:5792.9897
# number:0:epoch [1/30], loss:5537.8232
# number:0:epoch [1/30], loss:5396.4307
# number:0:epoch [1/30], loss:5596.8931
# number:0:epoch [1/30], loss:5554.7681
# number:0:epoch [1/30], loss:5477.0215
# number:0:epoch [1/30], loss:5749.0054
# number:0:epoch [1/30], loss:5723.1636
# number:0:epoch [1/30], loss:5485.5854
# number:0:epoch [1/30], loss:5606.6401
# number:0:epoch [1/30], loss:5550.0078
# number:0:epoch [1/30], loss:5366.5488
# number:0:epoch [1/30], loss:5547.0986
# number:0:epoch [1/30], loss:5378.3643
# number:0:epoch [1/30], loss:5625.9302
# number:0:epoch [1/30], loss:5378.3657
# number:0:epoch [1/30], loss:5274.2681
# number:0:epoch [1/30], loss:5238.6250
# number:0:epoch [1/30], loss:5233.7397
# number:0:epoch [1/30], loss:5001.8354
# number:0:epoch [1/30], loss:5169.3013
# number:0:epoch [1/30], loss:5311.4375
# number:0:epoch [1/30], loss:5089.8755
# number:0:epoch [1/30], loss:5129.1504
# number:0:epoch [1/30], loss:5236.3779
# number:0:epoch [1/30], loss:5261.9468
# number:0:epoch [1/30], loss:5104.4692
# number:0:epoch [1/30], loss:5185.2090
# number:0:epoch [1/30], loss:4926.3350
# number:0:epoch [1/30], loss:4912.4790
# number:0:epoch [1/30], loss:4948.0400
# number:0:epoch [1/30], loss:5033.2759
# number:0:epoch [1/30], loss:4919.4404
# number:0:epoch [1/30], loss:5112.6543
# number:0:epoch [1/30], loss:4791.3354
# number:0:epoch [1/30], loss:4789.3623
# number:0:epoch [1/30], loss:4855.0776
# number:0:epoch [1/30], loss:4839.7163
# number:0:epoch [1/30], loss:4784.4858
# number:0:epoch [1/30], loss:4691.0259
# number:0:epoch [1/30], loss:4828.9219
# number:0:epoch [1/30], loss:4844.4658
# number:0:epoch [1/30], loss:4648.2578
# number:0:epoch [1/30], loss:4681.5713
# number:0:epoch [1/30], loss:4616.2827
# number:0:epoch [1/30], loss:4689.2656
# number:0:epoch [1/30], loss:4553.1191
# number:0:epoch [1/30], loss:5011.2803
# number:0:epoch [1/30], loss:4431.3896
# number:0:epoch [1/30], loss:4660.6284
# number:0:epoch [1/30], loss:4752.6611
# number:0:epoch [1/30], loss:4533.9980
# number:0:epoch [1/30], loss:4624.5356
# number:0:epoch [1/30], loss:4481.0137
# number:0:epoch [1/30], loss:4635.9629
# number:0:epoch [1/30], loss:4499.9937
# number:0:epoch [1/30], loss:4629.1885
# number:0:epoch [1/30], loss:4405.5581
# number:0:epoch [1/30], loss:4685.0288
# number:0:epoch [1/30], loss:4609.2368
# number:0:epoch [1/30], loss:4594.4766
# number:0:epoch [1/30], loss:4472.7061
# number:0:epoch [1/30], loss:4794.0635
# number:0:epoch [1/30], loss:4490.9639
# number:0:epoch [1/30], loss:4654.4121
# number:0:epoch [1/30], loss:4439.1958
# number:0:epoch [1/30], loss:4641.2168
# number:0:epoch [1/30], loss:4420.0806
# number:0:epoch [1/30], loss:4439.6860
# number:0:epoch [1/30], loss:4312.7949
# number:0:epoch [1/30], loss:4438.2383
# number:0:epoch [1/30], loss:4557.8843
# number:0:epoch [1/30], loss:4352.6523
# number:0:epoch [1/30], loss:4458.7407
# number:0:epoch [1/30], loss:4450.7202
# number:0:epoch [1/30], loss:4749.9932
# number:0:epoch [1/30], loss:4428.6299
# number:0:epoch [1/30], loss:2802.1067
# number:1:epoch [1/30], loss:14140.1357
# number:1:epoch [1/30], loss:8461.6611
# number:1:epoch [1/30], loss:6063.8369
# number:1:epoch [1/30], loss:4210.7285
# number:1:epoch [1/30], loss:3478.2397
# number:1:epoch [1/30], loss:3456.0083
# number:1:epoch [1/30], loss:3210.9893
# number:1:epoch [1/30], loss:3082.6653
# number:1:epoch [1/30], loss:3282.6943
# number:1:epoch [1/30], loss:3102.6052
# number:1:epoch [1/30], loss:3163.6987
# number:1:epoch [1/30], loss:3002.0142
# number:1:epoch [1/30], loss:2991.8831
# number:1:epoch [1/30], loss:3091.6838
# number:1:epoch [1/30], loss:2983.4146
# number:1:epoch [1/30], loss:3054.8345
# number:1:epoch [1/30], loss:2961.3713
# number:1:epoch [1/30], loss:3119.2507
# number:1:epoch [1/30], loss:2851.8652
# number:1:epoch [1/30], loss:2780.6296
# number:1:epoch [1/30], loss:2848.8982
# number:1:epoch [1/30], loss:2989.9714
# number:1:epoch [1/30], loss:2953.5054
# number:1:epoch [1/30], loss:3105.1216
# number:1:epoch [1/30], loss:3088.1465
# number:1:epoch [1/30], loss:2818.1201
# number:1:epoch [1/30], loss:2716.1685
# number:1:epoch [1/30], loss:2669.8467
# number:1:epoch [1/30], loss:2895.2542
# number:1:epoch [1/30], loss:2561.7283
# number:1:epoch [1/30], loss:2836.8552
# number:1:epoch [1/30], loss:2960.0715
# number:1:epoch [1/30], loss:2633.4072
# number:1:epoch [1/30], loss:2653.7222
# number:1:epoch [1/30], loss:2746.2395
# number:1:epoch [1/30], loss:2674.7351
# number:1:epoch [1/30], loss:2520.8315
# number:1:epoch [1/30], loss:2477.5742
# number:1:epoch [1/30], loss:2552.9771
# number:1:epoch [1/30], loss:2553.2446
# number:1:epoch [1/30], loss:2608.9646
# number:1:epoch [1/30], loss:2446.2290
# number:1:epoch [1/30], loss:2362.2908
# number:1:epoch [1/30], loss:2190.2898
# number:1:epoch [1/30], loss:2511.5457
# number:1:epoch [1/30], loss:2211.3289
# number:1:epoch [1/30], loss:2215.9604
# number:1:epoch [1/30], loss:2217.3545
# number:1:epoch [1/30], loss:2208.6494
# number:1:epoch [1/30], loss:2345.5972
# number:1:epoch [1/30], loss:2210.7144
# number:1:epoch [1/30], loss:2153.1475
# number:1:epoch [1/30], loss:2244.9365
# number:1:epoch [1/30], loss:2253.3098
# number:1:epoch [1/30], loss:2162.7820
# number:1:epoch [1/30], loss:2127.4602
# number:1:epoch [1/30], loss:2147.6548
# number:1:epoch [1/30], loss:2225.0508
# number:1:epoch [1/30], loss:2247.8586
# number:1:epoch [1/30], loss:2046.2711
# number:1:epoch [1/30], loss:2094.4897
# number:1:epoch [1/30], loss:2381.2056
# number:1:epoch [1/30], loss:2019.8701
# number:1:epoch [1/30], loss:2081.6528
# number:1:epoch [1/30], loss:2096.4719
# number:1:epoch [1/30], loss:2246.3079
# number:1:epoch [1/30], loss:2188.4751
# number:1:epoch [1/30], loss:2023.5842
# number:1:epoch [1/30], loss:2212.2300
# number:1:epoch [1/30], loss:2179.0605
# number:1:epoch [1/30], loss:2088.5977
# number:1:epoch [1/30], loss:1941.4097
# number:1:epoch [1/30], loss:2125.4014
# number:1:epoch [1/30], loss:1966.2556
# number:1:epoch [1/30], loss:2065.2053
# number:1:epoch [1/30], loss:2124.9563
# number:1:epoch [1/30], loss:2010.6538
# number:1:epoch [1/30], loss:1959.0750
# number:1:epoch [1/30], loss:1973.9901
# number:1:epoch [1/30], loss:1930.0336
# number:1:epoch [1/30], loss:2210.6431
# number:1:epoch [1/30], loss:2020.8534
# number:1:epoch [1/30], loss:1994.6859
# number:1:epoch [1/30], loss:1880.1405
# number:1:epoch [1/30], loss:2001.2369
# number:1:epoch [1/30], loss:1921.8247
# number:1:epoch [1/30], loss:2211.6204
# number:1:epoch [1/30], loss:2156.8311
# number:1:epoch [1/30], loss:1961.0623
# number:1:epoch [1/30], loss:1953.2899
# number:1:epoch [1/30], loss:2075.5068
# number:1:epoch [1/30], loss:2117.9297
# number:1:epoch [1/30], loss:2152.0825
# number:1:epoch [1/30], loss:1987.8175
# number:1:epoch [1/30], loss:2217.6335
# number:1:epoch [1/30], loss:2036.3083
# number:1:epoch [1/30], loss:2043.4995
# number:1:epoch [1/30], loss:2035.4396
# number:1:epoch [1/30], loss:699.9791
# number:2:epoch [1/30], loss:14042.4336
# number:2:epoch [1/30], loss:9961.7246
# number:2:epoch [1/30], loss:7352.5107
# number:2:epoch [1/30], loss:6516.3667
# number:2:epoch [1/30], loss:6434.6670
# number:2:epoch [1/30], loss:6018.6738
# number:2:epoch [1/30], loss:5957.8989
# number:2:epoch [1/30], loss:5871.2607
# number:2:epoch [1/30], loss:5636.0522
# number:2:epoch [1/30], loss:5973.9443
# number:2:epoch [1/30], loss:5865.5938
# number:2:epoch [1/30], loss:5845.6680
# number:2:epoch [1/30], loss:5915.7930
# number:2:epoch [1/30], loss:5981.2383
# number:2:epoch [1/30], loss:5659.4414
# number:2:epoch [1/30], loss:5611.3628
# number:2:epoch [1/30], loss:5672.2363
# number:2:epoch [1/30], loss:5889.4014
# number:2:epoch [1/30], loss:5310.2769
# number:2:epoch [1/30], loss:5546.9360
# number:2:epoch [1/30], loss:5384.7935
# number:2:epoch [1/30], loss:5622.6001
# number:2:epoch [1/30], loss:5608.3237
# number:2:epoch [1/30], loss:5367.8149
# number:2:epoch [1/30], loss:5704.6753
# number:2:epoch [1/30], loss:5624.5454
# number:2:epoch [1/30], loss:5455.6084
# number:2:epoch [1/30], loss:5548.0781
# number:2:epoch [1/30], loss:5341.5967
# number:2:epoch [1/30], loss:5506.9668
# number:2:epoch [1/30], loss:5281.6860
# number:2:epoch [1/30], loss:5487.3052
# number:2:epoch [1/30], loss:5483.2241
# number:2:epoch [1/30], loss:5159.4263
# number:2:epoch [1/30], loss:5352.0190
# number:2:epoch [1/30], loss:5197.6270
# number:2:epoch [1/30], loss:5267.5518
# number:2:epoch [1/30], loss:5233.6562
# number:2:epoch [1/30], loss:5050.4790
# number:2:epoch [1/30], loss:5200.5659
# number:2:epoch [1/30], loss:5187.1611
# number:2:epoch [1/30], loss:4904.9409
# number:2:epoch [1/30], loss:5123.6670
# number:2:epoch [1/30], loss:5032.0366
# number:2:epoch [1/30], loss:5156.6260
# number:2:epoch [1/30], loss:5034.1523
# number:2:epoch [1/30], loss:5283.1973
# number:2:epoch [1/30], loss:4955.7427
# number:2:epoch [1/30], loss:5293.1909
# number:2:epoch [1/30], loss:5113.2539
# number:2:epoch [1/30], loss:5015.6465
# number:2:epoch [1/30], loss:5051.8965
# number:2:epoch [1/30], loss:4962.6245
# number:2:epoch [1/30], loss:5106.3857
# number:2:epoch [1/30], loss:5026.8452
# number:2:epoch [1/30], loss:5027.9722
# number:2:epoch [1/30], loss:5076.9653
# number:2:epoch [1/30], loss:5026.4248
# number:2:epoch [1/30], loss:4974.1108
# number:2:epoch [1/30], loss:5047.6992
# number:2:epoch [1/30], loss:4882.5396
# number:2:epoch [1/30], loss:5054.9502
# number:2:epoch [1/30], loss:4931.6978
# number:2:epoch [1/30], loss:5072.7534
# number:2:epoch [1/30], loss:5015.5620
# number:2:epoch [1/30], loss:5020.3853
# number:2:epoch [1/30], loss:4844.3110
# number:2:epoch [1/30], loss:4850.6484
# number:2:epoch [1/30], loss:4927.5103
# number:2:epoch [1/30], loss:4999.9312
# number:2:epoch [1/30], loss:4893.0059
# number:2:epoch [1/30], loss:5005.1997
# number:2:epoch [1/30], loss:5035.3374
# number:2:epoch [1/30], loss:5039.5195
# number:2:epoch [1/30], loss:4892.3970
# number:2:epoch [1/30], loss:4861.5083
# number:2:epoch [1/30], loss:4884.6147
# number:2:epoch [1/30], loss:4629.3130
# number:2:epoch [1/30], loss:4861.8291
# number:2:epoch [1/30], loss:4767.1035
# number:2:epoch [1/30], loss:4772.2622
# number:2:epoch [1/30], loss:4743.7979
# number:2:epoch [1/30], loss:4707.5610
# number:2:epoch [1/30], loss:4884.4937
# number:2:epoch [1/30], loss:4590.3721
# number:2:epoch [1/30], loss:4898.9360
# number:2:epoch [1/30], loss:4236.4463
# number:3:epoch [1/30], loss:14055.6162
# number:3:epoch [1/30], loss:9640.9717
# number:3:epoch [1/30], loss:6665.0405
# number:3:epoch [1/30], loss:5932.4062
# number:3:epoch [1/30], loss:5570.0723
# number:3:epoch [1/30], loss:5514.3486
# number:3:epoch [1/30], loss:5397.7080
# number:3:epoch [1/30], loss:5493.7788
# number:3:epoch [1/30], loss:5446.0059
# number:3:epoch [1/30], loss:5414.1606
# number:3:epoch [1/30], loss:5263.9790
# number:3:epoch [1/30], loss:5393.1748
# number:3:epoch [1/30], loss:5364.8271
# number:3:epoch [1/30], loss:5247.0801
# number:3:epoch [1/30], loss:5232.8760
# number:3:epoch [1/30], loss:4988.7534
# number:3:epoch [1/30], loss:5237.7397
# number:3:epoch [1/30], loss:5386.3516
# number:3:epoch [1/30], loss:5247.9189
# number:3:epoch [1/30], loss:5304.4878
# number:3:epoch [1/30], loss:5300.2622
# number:3:epoch [1/30], loss:5260.1055
# number:3:epoch [1/30], loss:5323.4468
# number:3:epoch [1/30], loss:5077.5439
# number:3:epoch [1/30], loss:5241.7129
# number:3:epoch [1/30], loss:5007.2290
# number:3:epoch [1/30], loss:5119.3794
# number:3:epoch [1/30], loss:5091.4321
# number:3:epoch [1/30], loss:5060.9429
# number:3:epoch [1/30], loss:5179.5596
# number:3:epoch [1/30], loss:4927.5957
# number:3:epoch [1/30], loss:4872.3677
# number:3:epoch [1/30], loss:4824.0273
# number:3:epoch [1/30], loss:4859.8208
# number:3:epoch [1/30], loss:4865.8950
# number:3:epoch [1/30], loss:4936.5884
# number:3:epoch [1/30], loss:4682.4775
# number:3:epoch [1/30], loss:4805.9438
# number:3:epoch [1/30], loss:5154.0322
# number:3:epoch [1/30], loss:4655.4487
# number:3:epoch [1/30], loss:4515.2598
# number:3:epoch [1/30], loss:4572.2017
# number:3:epoch [1/30], loss:4542.5513
# number:3:epoch [1/30], loss:4553.2314
# number:3:epoch [1/30], loss:4737.9160
# number:3:epoch [1/30], loss:4524.6333
# number:3:epoch [1/30], loss:4656.4497
# number:3:epoch [1/30], loss:4558.4482
# number:3:epoch [1/30], loss:4649.6992
# number:3:epoch [1/30], loss:4699.2031
# number:3:epoch [1/30], loss:4756.6548
# number:3:epoch [1/30], loss:4756.0312
# number:3:epoch [1/30], loss:4611.6987
# number:3:epoch [1/30], loss:4658.1655
# number:3:epoch [1/30], loss:4781.5015
# number:3:epoch [1/30], loss:4580.6255
# number:3:epoch [1/30], loss:4699.1011
# number:3:epoch [1/30], loss:4684.7603
# number:3:epoch [1/30], loss:4568.9980
# number:3:epoch [1/30], loss:4696.8652
# number:3:epoch [1/30], loss:4839.4917
# number:3:epoch [1/30], loss:4497.3628
# number:3:epoch [1/30], loss:4687.8369
# number:3:epoch [1/30], loss:4484.5781
# number:3:epoch [1/30], loss:4435.1719
# number:3:epoch [1/30], loss:4661.0093
# number:3:epoch [1/30], loss:4475.9673
# number:3:epoch [1/30], loss:4763.9092
# number:3:epoch [1/30], loss:4548.0444
# number:3:epoch [1/30], loss:4565.6831
# number:3:epoch [1/30], loss:4592.8149
# number:3:epoch [1/30], loss:4608.9600
# number:3:epoch [1/30], loss:4631.9526
# number:3:epoch [1/30], loss:4530.6846
# number:3:epoch [1/30], loss:4795.7681
# number:3:epoch [1/30], loss:4574.6084
# number:3:epoch [1/30], loss:4570.3774
# number:3:epoch [1/30], loss:4461.9961
# number:3:epoch [1/30], loss:4482.4229
# number:3:epoch [1/30], loss:4378.6973
# number:3:epoch [1/30], loss:4690.1162
# number:3:epoch [1/30], loss:4654.2847
# number:3:epoch [1/30], loss:4345.5962
# number:3:epoch [1/30], loss:4556.3311
# number:3:epoch [1/30], loss:4391.5566
# number:3:epoch [1/30], loss:4420.2231
# number:3:epoch [1/30], loss:4470.4526
# number:3:epoch [1/30], loss:4386.8765
# number:3:epoch [1/30], loss:4508.0889
# number:3:epoch [1/30], loss:1908.9861
# number:4:epoch [1/30], loss:13990.9014
# number:4:epoch [1/30], loss:8810.2021
# number:4:epoch [1/30], loss:6292.6313
# number:4:epoch [1/30], loss:5466.3823
# number:4:epoch [1/30], loss:5004.2222
# number:4:epoch [1/30], loss:5403.1475
# number:4:epoch [1/30], loss:4927.8374
# number:4:epoch [1/30], loss:5084.3638
# number:4:epoch [1/30], loss:5002.3877
# number:4:epoch [1/30], loss:4823.3892
# number:4:epoch [1/30], loss:4898.4878
# number:4:epoch [1/30], loss:4957.1450
# number:4:epoch [1/30], loss:4929.1499
# number:4:epoch [1/30], loss:4970.8804
# number:4:epoch [1/30], loss:4889.4160
# number:4:epoch [1/30], loss:4793.0659
# number:4:epoch [1/30], loss:4693.3516
# number:4:epoch [1/30], loss:4606.3164
# number:4:epoch [1/30], loss:4723.8706
# number:4:epoch [1/30], loss:4793.2837
# number:4:epoch [1/30], loss:4936.3589
# number:4:epoch [1/30], loss:4472.0122
# number:4:epoch [1/30], loss:4639.1499
# number:4:epoch [1/30], loss:4803.8862
# number:4:epoch [1/30], loss:4823.0635
# number:4:epoch [1/30], loss:4613.3037
# number:4:epoch [1/30], loss:4599.8032
# number:4:epoch [1/30], loss:4739.6514
# number:4:epoch [1/30], loss:4673.4434
# number:4:epoch [1/30], loss:4772.1655
# number:4:epoch [1/30], loss:4527.7734
# number:4:epoch [1/30], loss:4715.4302
# number:4:epoch [1/30], loss:4610.5991
# number:4:epoch [1/30], loss:4643.0996
# number:4:epoch [1/30], loss:4393.3345
# number:4:epoch [1/30], loss:4466.9902
# number:4:epoch [1/30], loss:4449.2505
# number:4:epoch [1/30], loss:4764.4482
# number:4:epoch [1/30], loss:4409.2793
# number:4:epoch [1/30], loss:4566.2334
# number:4:epoch [1/30], loss:4502.8657
# number:4:epoch [1/30], loss:4342.5361
# number:4:epoch [1/30], loss:4207.7168
# number:4:epoch [1/30], loss:4309.4775
# number:4:epoch [1/30], loss:4370.6299
# number:4:epoch [1/30], loss:4337.8066
# number:4:epoch [1/30], loss:4199.7866
# number:4:epoch [1/30], loss:4315.2842
# number:4:epoch [1/30], loss:4222.7832
# number:4:epoch [1/30], loss:4093.4436
# number:4:epoch [1/30], loss:4266.5073
# number:4:epoch [1/30], loss:4489.0269
# number:4:epoch [1/30], loss:4252.9395
# number:4:epoch [1/30], loss:4307.4927
# number:4:epoch [1/30], loss:4257.2510
# number:4:epoch [1/30], loss:4372.6265
# number:4:epoch [1/30], loss:4229.9429
# number:4:epoch [1/30], loss:4177.0308
# number:4:epoch [1/30], loss:4161.4111
# number:4:epoch [1/30], loss:4424.6001
# number:4:epoch [1/30], loss:3980.4475
# number:4:epoch [1/30], loss:4319.3198
# number:4:epoch [1/30], loss:4245.5762
# number:4:epoch [1/30], loss:4046.2283
# number:4:epoch [1/30], loss:4057.7922
# number:4:epoch [1/30], loss:4140.5718
# number:4:epoch [1/30], loss:4052.3840
# number:4:epoch [1/30], loss:4048.3086
# number:4:epoch [1/30], loss:4077.9907
# number:4:epoch [1/30], loss:4282.4849
# number:4:epoch [1/30], loss:4055.5374
# number:4:epoch [1/30], loss:4054.0242
# number:4:epoch [1/30], loss:4071.7170
# number:4:epoch [1/30], loss:3951.7336
# number:4:epoch [1/30], loss:4181.7495
# number:4:epoch [1/30], loss:4066.1968
# number:4:epoch [1/30], loss:4250.1367
# number:4:epoch [1/30], loss:3976.8843
# number:4:epoch [1/30], loss:3894.1958
# number:4:epoch [1/30], loss:3969.1196
# number:4:epoch [1/30], loss:4042.8923
# number:4:epoch [1/30], loss:3870.5598
# number:4:epoch [1/30], loss:4154.4521
# number:4:epoch [1/30], loss:4024.8262
# number:4:epoch [1/30], loss:3998.1006
# number:4:epoch [1/30], loss:714.8828
# number:5:epoch [1/30], loss:14087.1865
# number:5:epoch [1/30], loss:9999.8145
# number:5:epoch [1/30], loss:6981.5679
# number:5:epoch [1/30], loss:6041.0537
# number:5:epoch [1/30], loss:5898.7334
# number:5:epoch [1/30], loss:5653.8569
# number:5:epoch [1/30], loss:5656.7134
# number:5:epoch [1/30], loss:5678.6680
# number:5:epoch [1/30], loss:5272.0479
# number:5:epoch [1/30], loss:5605.8682
# number:5:epoch [1/30], loss:5411.0420
# number:5:epoch [1/30], loss:5333.5337
# number:5:epoch [1/30], loss:5395.3818
# number:5:epoch [1/30], loss:5414.9604
# number:5:epoch [1/30], loss:5468.5151
# number:5:epoch [1/30], loss:5285.8560
# number:5:epoch [1/30], loss:5381.6221
# number:5:epoch [1/30], loss:5225.6904
# number:5:epoch [1/30], loss:5170.3145
# number:5:epoch [1/30], loss:5546.1689
# number:5:epoch [1/30], loss:5309.1152
# number:5:epoch [1/30], loss:5017.1821
# number:5:epoch [1/30], loss:5065.6890
# number:5:epoch [1/30], loss:4961.1870
# number:5:epoch [1/30], loss:5017.7358
# number:5:epoch [1/30], loss:4723.4482
# number:5:epoch [1/30], loss:5088.8081
# number:5:epoch [1/30], loss:4952.3940
# number:5:epoch [1/30], loss:4977.8564
# number:5:epoch [1/30], loss:4905.5996
# number:5:epoch [1/30], loss:4865.9619
# number:5:epoch [1/30], loss:4981.2417
# number:5:epoch [1/30], loss:4976.9434
# number:5:epoch [1/30], loss:4679.1807
# number:5:epoch [1/30], loss:4617.5747
# number:5:epoch [1/30], loss:4907.3276
# number:5:epoch [1/30], loss:4635.3374
# number:5:epoch [1/30], loss:4737.9321
# number:5:epoch [1/30], loss:4787.7148
# number:5:epoch [1/30], loss:4831.1895
# number:5:epoch [1/30], loss:4777.3389
# number:5:epoch [1/30], loss:4729.4604
# number:5:epoch [1/30], loss:4650.6826
# number:5:epoch [1/30], loss:4739.4448
# number:5:epoch [1/30], loss:4855.0586
# number:5:epoch [1/30], loss:4678.3096
# number:5:epoch [1/30], loss:4747.4102
# number:5:epoch [1/30], loss:4705.1597
# number:5:epoch [1/30], loss:4854.7334
# number:5:epoch [1/30], loss:4567.7705
# number:5:epoch [1/30], loss:4857.8887
# number:5:epoch [1/30], loss:4845.0488
# number:5:epoch [1/30], loss:4719.3110
# number:5:epoch [1/30], loss:4397.2275
# number:5:epoch [1/30], loss:4545.8721
# number:5:epoch [1/30], loss:4553.9961
# number:5:epoch [1/30], loss:4551.7646
# number:5:epoch [1/30], loss:4414.7603
# number:5:epoch [1/30], loss:4666.3687
# number:5:epoch [1/30], loss:4680.6680
# number:5:epoch [1/30], loss:4722.2461
# number:5:epoch [1/30], loss:4636.6616
# number:5:epoch [1/30], loss:4566.7578
# number:5:epoch [1/30], loss:4468.3457
# number:5:epoch [1/30], loss:4487.6807
# number:5:epoch [1/30], loss:4508.4302
# number:5:epoch [1/30], loss:4506.2827
# number:5:epoch [1/30], loss:4683.0728
# number:5:epoch [1/30], loss:4492.7998
# number:5:epoch [1/30], loss:4700.7729
# number:5:epoch [1/30], loss:4347.7759
# number:5:epoch [1/30], loss:4449.4585
# number:5:epoch [1/30], loss:4654.5933
# number:5:epoch [1/30], loss:4526.7241
# number:5:epoch [1/30], loss:4340.3286
# number:5:epoch [1/30], loss:4450.2129
# number:5:epoch [1/30], loss:4528.0708
# number:5:epoch [1/30], loss:4569.7656
# number:5:epoch [1/30], loss:4365.1001
# number:5:epoch [1/30], loss:976.4662
# number:6:epoch [1/30], loss:14073.6445
# number:6:epoch [1/30], loss:9416.6387
# number:6:epoch [1/30], loss:6904.6943
# number:6:epoch [1/30], loss:5697.6416
# number:6:epoch [1/30], loss:5727.1582
# number:6:epoch [1/30], loss:5187.9985
# number:6:epoch [1/30], loss:5035.7437
# number:6:epoch [1/30], loss:5187.6055
# number:6:epoch [1/30], loss:5140.1167
# number:6:epoch [1/30], loss:5346.0728
# number:6:epoch [1/30], loss:4960.8115
# number:6:epoch [1/30], loss:5066.2173
# number:6:epoch [1/30], loss:5078.5625
# number:6:epoch [1/30], loss:4825.2681
# number:6:epoch [1/30], loss:4565.0693
# number:6:epoch [1/30], loss:4915.0679
# number:6:epoch [1/30], loss:4851.7515
# number:6:epoch [1/30], loss:4966.2354
# number:6:epoch [1/30], loss:5094.2725
# number:6:epoch [1/30], loss:4903.9390
# number:6:epoch [1/30], loss:5119.6016
# number:6:epoch [1/30], loss:4754.7744
# number:6:epoch [1/30], loss:4758.4136
# number:6:epoch [1/30], loss:4958.4980
# number:6:epoch [1/30], loss:4773.4316
# number:6:epoch [1/30], loss:4752.8115
# number:6:epoch [1/30], loss:5072.3281
# number:6:epoch [1/30], loss:5037.3096
# number:6:epoch [1/30], loss:4663.9570
# number:6:epoch [1/30], loss:4542.5898
# number:6:epoch [1/30], loss:4765.1387
# number:6:epoch [1/30], loss:4762.0371
# number:6:epoch [1/30], loss:4571.0020
# number:6:epoch [1/30], loss:4614.3706
# number:6:epoch [1/30], loss:4637.2842
# number:6:epoch [1/30], loss:4483.2480
# number:6:epoch [1/30], loss:4323.4258
# number:6:epoch [1/30], loss:4424.1509
# number:6:epoch [1/30], loss:4454.7988
# number:6:epoch [1/30], loss:4344.6421
# number:6:epoch [1/30], loss:4299.2739
# number:6:epoch [1/30], loss:4840.2358
# number:6:epoch [1/30], loss:4378.0430
# number:6:epoch [1/30], loss:4584.4209
# number:6:epoch [1/30], loss:4403.7500
# number:6:epoch [1/30], loss:4375.4351
# number:6:epoch [1/30], loss:4305.5688
# number:6:epoch [1/30], loss:4240.4922
# number:6:epoch [1/30], loss:4425.9717
# number:6:epoch [1/30], loss:4071.8433
# number:6:epoch [1/30], loss:4212.1904
# number:6:epoch [1/30], loss:4052.3794
# number:6:epoch [1/30], loss:4184.9702
# number:6:epoch [1/30], loss:4217.4268
# number:6:epoch [1/30], loss:4186.7119
# number:6:epoch [1/30], loss:4201.3589
# number:6:epoch [1/30], loss:4186.4561
# number:6:epoch [1/30], loss:4238.3911
# number:6:epoch [1/30], loss:4255.7075
# number:6:epoch [1/30], loss:4289.2651
# number:6:epoch [1/30], loss:4324.9404
# number:6:epoch [1/30], loss:3957.8279
# number:6:epoch [1/30], loss:4071.7253
# number:6:epoch [1/30], loss:4103.0400
# number:6:epoch [1/30], loss:4205.9878
# number:6:epoch [1/30], loss:4130.2256
# number:6:epoch [1/30], loss:4084.8352
# number:6:epoch [1/30], loss:4300.6353
# number:6:epoch [1/30], loss:4101.2368
# number:6:epoch [1/30], loss:4236.3296
# number:6:epoch [1/30], loss:4161.1787
# number:6:epoch [1/30], loss:4137.5820
# number:6:epoch [1/30], loss:4102.2495
# number:6:epoch [1/30], loss:4221.9829
# number:6:epoch [1/30], loss:4132.0220
# number:6:epoch [1/30], loss:4254.2661
# number:6:epoch [1/30], loss:4084.2307
# number:6:epoch [1/30], loss:4233.8511
# number:6:epoch [1/30], loss:4026.7126
# number:6:epoch [1/30], loss:4107.7476
# number:6:epoch [1/30], loss:3932.6531
# number:6:epoch [1/30], loss:3939.8140
# number:6:epoch [1/30], loss:4054.6436
# number:6:epoch [1/30], loss:3976.7861
# number:6:epoch [1/30], loss:4022.2358
# number:6:epoch [1/30], loss:4073.2803
# number:6:epoch [1/30], loss:421.5656
# number:7:epoch [1/30], loss:13957.1885
# number:7:epoch [1/30], loss:8676.2842
# number:7:epoch [1/30], loss:6140.8311
# number:7:epoch [1/30], loss:5255.5625
# number:7:epoch [1/30], loss:5042.9380
# number:7:epoch [1/30], loss:4792.9497
# number:7:epoch [1/30], loss:4805.3628
# number:7:epoch [1/30], loss:4758.0762
# number:7:epoch [1/30], loss:4621.0942
# number:7:epoch [1/30], loss:4667.9272
# number:7:epoch [1/30], loss:4456.0215
# number:7:epoch [1/30], loss:4622.3208
# number:7:epoch [1/30], loss:4727.4375
# number:7:epoch [1/30], loss:4602.0684
# number:7:epoch [1/30], loss:4603.2441
# number:7:epoch [1/30], loss:4567.1528
# number:7:epoch [1/30], loss:4354.5630
# number:7:epoch [1/30], loss:4567.8564
# number:7:epoch [1/30], loss:4583.4697
# number:7:epoch [1/30], loss:4332.7466
# number:7:epoch [1/30], loss:4577.6919
# number:7:epoch [1/30], loss:4500.7993
# number:7:epoch [1/30], loss:4324.7271
# number:7:epoch [1/30], loss:4420.1211
# number:7:epoch [1/30], loss:4212.6724
# number:7:epoch [1/30], loss:4336.8101
# number:7:epoch [1/30], loss:4271.7388
# number:7:epoch [1/30], loss:4427.3252
# number:7:epoch [1/30], loss:4393.6719
# number:7:epoch [1/30], loss:4454.4561
# number:7:epoch [1/30], loss:4229.4033
# number:7:epoch [1/30], loss:4040.9639
# number:7:epoch [1/30], loss:4264.0381
# number:7:epoch [1/30], loss:4319.7529
# number:7:epoch [1/30], loss:4237.5142
# number:7:epoch [1/30], loss:4087.7861
# number:7:epoch [1/30], loss:3911.5864
# number:7:epoch [1/30], loss:4053.3328
# number:7:epoch [1/30], loss:3832.4966
# number:7:epoch [1/30], loss:3969.9761
# number:7:epoch [1/30], loss:4290.5947
# number:7:epoch [1/30], loss:4017.7642
# number:7:epoch [1/30], loss:4174.0327
# number:7:epoch [1/30], loss:3896.0330
# number:7:epoch [1/30], loss:3882.4434
# number:7:epoch [1/30], loss:4025.7993
# number:7:epoch [1/30], loss:3893.7483
# number:7:epoch [1/30], loss:3879.8752
# number:7:epoch [1/30], loss:3942.6057
# number:7:epoch [1/30], loss:3738.6863
# number:7:epoch [1/30], loss:3523.2014
# number:7:epoch [1/30], loss:3781.2253
# number:7:epoch [1/30], loss:4083.8210
# number:7:epoch [1/30], loss:3937.8230
# number:7:epoch [1/30], loss:3724.0913
# number:7:epoch [1/30], loss:3922.5674
# number:7:epoch [1/30], loss:3740.7188
# number:7:epoch [1/30], loss:4002.1226
# number:7:epoch [1/30], loss:3690.3506
# number:7:epoch [1/30], loss:3682.3472
# number:7:epoch [1/30], loss:3673.5281
# number:7:epoch [1/30], loss:3718.9551
# number:7:epoch [1/30], loss:3844.9922
# number:7:epoch [1/30], loss:3907.1331
# number:7:epoch [1/30], loss:3823.4575
# number:7:epoch [1/30], loss:3798.7097
# number:7:epoch [1/30], loss:3821.4087
# number:7:epoch [1/30], loss:3590.9585
# number:7:epoch [1/30], loss:3769.3154
# number:7:epoch [1/30], loss:3670.3411
# number:7:epoch [1/30], loss:3753.0769
# number:7:epoch [1/30], loss:3708.1475
# number:7:epoch [1/30], loss:3576.9551
# number:7:epoch [1/30], loss:3625.0383
# number:7:epoch [1/30], loss:3897.5195
# number:7:epoch [1/30], loss:3558.0637
# number:7:epoch [1/30], loss:3627.4373
# number:7:epoch [1/30], loss:3549.4966
# number:7:epoch [1/30], loss:3589.4749
# number:7:epoch [1/30], loss:3739.4253
# number:7:epoch [1/30], loss:3578.3604
# number:7:epoch [1/30], loss:3686.9409
# number:7:epoch [1/30], loss:3447.1575
# number:7:epoch [1/30], loss:3529.8533
# number:7:epoch [1/30], loss:3629.4556
# number:7:epoch [1/30], loss:3454.5527
# number:7:epoch [1/30], loss:3625.7397
# number:7:epoch [1/30], loss:3747.1487
# number:7:epoch [1/30], loss:3756.1414
# number:7:epoch [1/30], loss:3422.6465
# number:7:epoch [1/30], loss:3580.8848
# number:7:epoch [1/30], loss:78.7347
# number:8:epoch [1/30], loss:14017.8242
# number:8:epoch [1/30], loss:10108.6797
# number:8:epoch [1/30], loss:7034.4673
# number:8:epoch [1/30], loss:6208.7183
# number:8:epoch [1/30], loss:5623.8354
# number:8:epoch [1/30], loss:6006.0850
# number:8:epoch [1/30], loss:5413.3662
# number:8:epoch [1/30], loss:5354.9653
# number:8:epoch [1/30], loss:5473.8721
# number:8:epoch [1/30], loss:5467.7451
# number:8:epoch [1/30], loss:5510.1333
# number:8:epoch [1/30], loss:5202.5176
# number:8:epoch [1/30], loss:5505.1367
# number:8:epoch [1/30], loss:5066.6587
# number:8:epoch [1/30], loss:5330.3892
# number:8:epoch [1/30], loss:5106.5537
# number:8:epoch [1/30], loss:5631.0464
# number:8:epoch [1/30], loss:5161.1147
# number:8:epoch [1/30], loss:5325.3896
# number:8:epoch [1/30], loss:5318.6938
# number:8:epoch [1/30], loss:5323.3066
# number:8:epoch [1/30], loss:5334.4634
# number:8:epoch [1/30], loss:5561.3735
# number:8:epoch [1/30], loss:5058.8032
# number:8:epoch [1/30], loss:5166.1846
# number:8:epoch [1/30], loss:5203.6968
# number:8:epoch [1/30], loss:5324.0088
# number:8:epoch [1/30], loss:5151.7358
# number:8:epoch [1/30], loss:5229.1123
# number:8:epoch [1/30], loss:5095.9062
# number:8:epoch [1/30], loss:5117.9995
# number:8:epoch [1/30], loss:5201.5127
# number:8:epoch [1/30], loss:4974.0151
# number:8:epoch [1/30], loss:4926.2363
# number:8:epoch [1/30], loss:5056.1362
# number:8:epoch [1/30], loss:4956.6743
# number:8:epoch [1/30], loss:5071.7061
# number:8:epoch [1/30], loss:5058.2354
# number:8:epoch [1/30], loss:4991.6436
# number:8:epoch [1/30], loss:4876.0195
# number:8:epoch [1/30], loss:4943.5015
# number:8:epoch [1/30], loss:4778.4526
# number:8:epoch [1/30], loss:5304.0742
# number:8:epoch [1/30], loss:4942.7061
# number:8:epoch [1/30], loss:4831.6123
# number:8:epoch [1/30], loss:4591.4346
# number:8:epoch [1/30], loss:4608.8477
# number:8:epoch [1/30], loss:4808.9985
# number:8:epoch [1/30], loss:4751.1445
# number:8:epoch [1/30], loss:4669.4927
# number:8:epoch [1/30], loss:4763.7607
# number:8:epoch [1/30], loss:4619.5083
# number:8:epoch [1/30], loss:4707.1748
# number:8:epoch [1/30], loss:4618.7021
# number:8:epoch [1/30], loss:4759.1929
# number:8:epoch [1/30], loss:5032.2617
# number:8:epoch [1/30], loss:4926.8579
# number:8:epoch [1/30], loss:4899.3950
# number:8:epoch [1/30], loss:4727.3179
# number:8:epoch [1/30], loss:4746.7964
# number:8:epoch [1/30], loss:4647.0146
# number:8:epoch [1/30], loss:4653.7739
# number:8:epoch [1/30], loss:4891.3296
# number:8:epoch [1/30], loss:5045.4277
# number:8:epoch [1/30], loss:4453.3276
# number:8:epoch [1/30], loss:4802.0547
# number:8:epoch [1/30], loss:4745.8120
# number:8:epoch [1/30], loss:4881.6602
# number:8:epoch [1/30], loss:4683.4438
# number:8:epoch [1/30], loss:4692.0269
# number:8:epoch [1/30], loss:4510.0659
# number:8:epoch [1/30], loss:4815.4092
# number:8:epoch [1/30], loss:4789.7646
# number:8:epoch [1/30], loss:4549.2783
# number:8:epoch [1/30], loss:4735.8936
# number:8:epoch [1/30], loss:4548.8008
# number:8:epoch [1/30], loss:4715.7134
# number:8:epoch [1/30], loss:4893.6753
# number:8:epoch [1/30], loss:4747.8887
# number:8:epoch [1/30], loss:4712.5215
# number:8:epoch [1/30], loss:4845.8691
# number:8:epoch [1/30], loss:4778.2490
# number:8:epoch [1/30], loss:4656.9097
# number:8:epoch [1/30], loss:4579.3105
# number:8:epoch [1/30], loss:4393.1216
# number:9:epoch [1/30], loss:14119.3066
# number:9:epoch [1/30], loss:8928.2617
# number:9:epoch [1/30], loss:6350.1919
# number:9:epoch [1/30], loss:5495.7090
# number:9:epoch [1/30], loss:4915.0444
# number:9:epoch [1/30], loss:4688.1426
# number:9:epoch [1/30], loss:4808.5537
# number:9:epoch [1/30], loss:4859.6357
# number:9:epoch [1/30], loss:4740.3374
# number:9:epoch [1/30], loss:4594.9927
# number:9:epoch [1/30], loss:4703.8535
# number:9:epoch [1/30], loss:4648.4688
# number:9:epoch [1/30], loss:4771.3853
# number:9:epoch [1/30], loss:4328.6294
# number:9:epoch [1/30], loss:4443.6880
# number:9:epoch [1/30], loss:4526.7681
# number:9:epoch [1/30], loss:4522.8818
# number:9:epoch [1/30], loss:4638.1230
# number:9:epoch [1/30], loss:4341.3535
# number:9:epoch [1/30], loss:4429.4355
# number:9:epoch [1/30], loss:4673.5249
# number:9:epoch [1/30], loss:4339.0176
# number:9:epoch [1/30], loss:4577.3560
# number:9:epoch [1/30], loss:4429.6846
# number:9:epoch [1/30], loss:4474.2227
# number:9:epoch [1/30], loss:4461.2471
# number:9:epoch [1/30], loss:4305.5703
# number:9:epoch [1/30], loss:4251.7280
# number:9:epoch [1/30], loss:4418.9692
# number:9:epoch [1/30], loss:4379.3511
# number:9:epoch [1/30], loss:4402.7212
# number:9:epoch [1/30], loss:4549.1543
# number:9:epoch [1/30], loss:4333.3936
# number:9:epoch [1/30], loss:4311.9023
# number:9:epoch [1/30], loss:4138.1855
# number:9:epoch [1/30], loss:4300.2095
# number:9:epoch [1/30], loss:4234.8833
# number:9:epoch [1/30], loss:4016.5710
# number:9:epoch [1/30], loss:4071.6531
# number:9:epoch [1/30], loss:4330.0112
# number:9:epoch [1/30], loss:4338.4229
# number:9:epoch [1/30], loss:4162.9521
# number:9:epoch [1/30], loss:4034.2876
# number:9:epoch [1/30], loss:4066.7266
# number:9:epoch [1/30], loss:4012.9910
# number:9:epoch [1/30], loss:3902.1646
# number:9:epoch [1/30], loss:3820.5078
# number:9:epoch [1/30], loss:3814.5374
# number:9:epoch [1/30], loss:4061.0806
# number:9:epoch [1/30], loss:4081.3457
# number:9:epoch [1/30], loss:3825.8257
# number:9:epoch [1/30], loss:3765.5283
# number:9:epoch [1/30], loss:4042.5632
# number:9:epoch [1/30], loss:3840.7139
# number:9:epoch [1/30], loss:4003.5339
# number:9:epoch [1/30], loss:4009.7239
# number:9:epoch [1/30], loss:3959.2395
# number:9:epoch [1/30], loss:3800.5039
# number:9:epoch [1/30], loss:3899.5854
# number:9:epoch [1/30], loss:3772.6843
# number:9:epoch [1/30], loss:3782.7876
# number:9:epoch [1/30], loss:3677.8079
# number:9:epoch [1/30], loss:3799.7129
# number:9:epoch [1/30], loss:3866.1213
# number:9:epoch [1/30], loss:3738.2854
# number:9:epoch [1/30], loss:3780.3733
# number:9:epoch [1/30], loss:3939.7908
# number:9:epoch [1/30], loss:3909.4480
# number:9:epoch [1/30], loss:3795.1946
# number:9:epoch [1/30], loss:3728.0476
# number:9:epoch [1/30], loss:3718.9331
# number:9:epoch [1/30], loss:3809.5254
# number:9:epoch [1/30], loss:3805.9031
# number:9:epoch [1/30], loss:3793.5491
# number:9:epoch [1/30], loss:3681.7563
# number:9:epoch [1/30], loss:3794.4756
# number:9:epoch [1/30], loss:3741.2361
# number:9:epoch [1/30], loss:3544.2019
# number:9:epoch [1/30], loss:3970.4197
# number:9:epoch [1/30], loss:3856.1416
# number:9:epoch [1/30], loss:3773.3467
# number:9:epoch [1/30], loss:3601.8044
# number:9:epoch [1/30], loss:3467.1147
# number:9:epoch [1/30], loss:3769.9741
# number:9:epoch [1/30], loss:3522.1855
# number:9:epoch [1/30], loss:3479.5530
# number:9:epoch [1/30], loss:3762.4417
# number:9:epoch [1/30], loss:774.6548
# number:0:epoch [2/30], loss:4508.3159
# number:0:epoch [2/30], loss:4416.6494
# number:0:epoch [2/30], loss:4452.5317
# number:0:epoch [2/30], loss:4283.8315
# number:0:epoch [2/30], loss:4303.6904
# number:0:epoch [2/30], loss:4380.7642
# number:0:epoch [2/30], loss:4270.6475
# number:0:epoch [2/30], loss:4436.1255
# number:0:epoch [2/30], loss:4583.9355
# number:0:epoch [2/30], loss:4435.5928
# number:0:epoch [2/30], loss:4371.5498
# number:0:epoch [2/30], loss:4563.9854
# number:0:epoch [2/30], loss:4353.1685
# number:0:epoch [2/30], loss:4483.7925
# number:0:epoch [2/30], loss:4361.3062
# number:0:epoch [2/30], loss:4193.0249
# number:0:epoch [2/30], loss:4414.3550
# number:0:epoch [2/30], loss:4445.2476
# number:0:epoch [2/30], loss:4355.1235
# number:0:epoch [2/30], loss:4360.7021
# number:0:epoch [2/30], loss:4228.7124
# number:0:epoch [2/30], loss:4631.4502
# number:0:epoch [2/30], loss:4221.8320
# number:0:epoch [2/30], loss:4285.6167
# number:0:epoch [2/30], loss:4253.0659
# number:0:epoch [2/30], loss:4246.2227
# number:0:epoch [2/30], loss:4275.3906
# number:0:epoch [2/30], loss:4287.0044
# number:0:epoch [2/30], loss:4403.4727
# number:0:epoch [2/30], loss:4232.7085
# number:0:epoch [2/30], loss:4390.2983
# number:0:epoch [2/30], loss:4361.5918
# number:0:epoch [2/30], loss:4371.4951
# number:0:epoch [2/30], loss:4326.1069
# number:0:epoch [2/30], loss:4433.6802
# number:0:epoch [2/30], loss:4205.3423
# number:0:epoch [2/30], loss:4485.1328
# number:0:epoch [2/30], loss:4349.0430
# number:0:epoch [2/30], loss:4267.9004
# number:0:epoch [2/30], loss:4318.6987
# number:0:epoch [2/30], loss:4410.1631
# number:0:epoch [2/30], loss:4321.9067
# number:0:epoch [2/30], loss:4196.7358
# number:0:epoch [2/30], loss:4240.1812
# number:0:epoch [2/30], loss:4181.0923
# number:0:epoch [2/30], loss:4185.4019
# number:0:epoch [2/30], loss:4264.9839
# number:0:epoch [2/30], loss:4319.1123
# number:0:epoch [2/30], loss:4375.6348
# number:0:epoch [2/30], loss:4143.7563
# number:0:epoch [2/30], loss:4252.3423
# number:0:epoch [2/30], loss:4501.6865
# number:0:epoch [2/30], loss:4290.1567
# number:0:epoch [2/30], loss:4215.2935
# number:0:epoch [2/30], loss:4200.8091
# number:0:epoch [2/30], loss:4190.3569
# number:0:epoch [2/30], loss:4094.5981
# number:0:epoch [2/30], loss:4068.4395
# number:0:epoch [2/30], loss:4333.6660
# number:0:epoch [2/30], loss:4400.6060
# number:0:epoch [2/30], loss:4351.4146
# number:0:epoch [2/30], loss:4300.1533
# number:0:epoch [2/30], loss:4341.6821
# number:0:epoch [2/30], loss:4258.3301
# number:0:epoch [2/30], loss:4304.2544
# number:0:epoch [2/30], loss:4167.5396
# number:0:epoch [2/30], loss:4343.3281
# number:0:epoch [2/30], loss:4160.9067
# number:0:epoch [2/30], loss:4302.2446
# number:0:epoch [2/30], loss:4122.5605
# number:0:epoch [2/30], loss:4329.0552
# number:0:epoch [2/30], loss:4225.7383
# number:0:epoch [2/30], loss:4225.7163
# number:0:epoch [2/30], loss:4407.5186
# number:0:epoch [2/30], loss:4117.3711
# number:0:epoch [2/30], loss:4200.4014
# number:0:epoch [2/30], loss:4230.9800
# number:0:epoch [2/30], loss:4269.9370
# number:0:epoch [2/30], loss:4227.6079
# number:0:epoch [2/30], loss:4020.4551
# number:0:epoch [2/30], loss:4228.6768
# number:0:epoch [2/30], loss:4073.9512
# number:0:epoch [2/30], loss:4252.9404
# number:0:epoch [2/30], loss:4263.7036
# number:0:epoch [2/30], loss:4172.5889
# number:0:epoch [2/30], loss:4132.0938
# number:0:epoch [2/30], loss:2527.7781
# number:1:epoch [2/30], loss:2090.9624
# number:1:epoch [2/30], loss:2111.2512
# number:1:epoch [2/30], loss:2065.5195
# number:1:epoch [2/30], loss:2135.5559
# number:1:epoch [2/30], loss:1963.0797
# number:1:epoch [2/30], loss:2066.2307
# number:1:epoch [2/30], loss:1939.9496
# number:1:epoch [2/30], loss:2075.4697
# number:1:epoch [2/30], loss:1917.1293
# number:1:epoch [2/30], loss:1922.7753
# number:1:epoch [2/30], loss:2044.7675
# number:1:epoch [2/30], loss:2054.2468
# number:1:epoch [2/30], loss:2033.1753
# number:1:epoch [2/30], loss:1932.9984
# number:1:epoch [2/30], loss:2112.9514
# number:1:epoch [2/30], loss:1982.5417
# number:1:epoch [2/30], loss:1987.5516
# number:1:epoch [2/30], loss:1996.2625
# number:1:epoch [2/30], loss:1884.9535
# number:1:epoch [2/30], loss:2008.1769
# number:1:epoch [2/30], loss:1937.1880
# number:1:epoch [2/30], loss:1933.0973
# number:1:epoch [2/30], loss:2112.5549
# number:1:epoch [2/30], loss:2142.4744
# number:1:epoch [2/30], loss:2024.2333
# number:1:epoch [2/30], loss:1886.6035
# number:1:epoch [2/30], loss:1922.7527
# number:1:epoch [2/30], loss:2088.5051
# number:1:epoch [2/30], loss:2191.5017
# number:1:epoch [2/30], loss:2082.3494
# number:1:epoch [2/30], loss:1876.3671
# number:1:epoch [2/30], loss:2080.1367
# number:1:epoch [2/30], loss:1887.4817
# number:1:epoch [2/30], loss:2004.4846
# number:1:epoch [2/30], loss:2029.3275
# number:1:epoch [2/30], loss:1980.5226
# number:1:epoch [2/30], loss:1885.2952
# number:1:epoch [2/30], loss:1963.8679
# number:1:epoch [2/30], loss:1928.1216
# number:1:epoch [2/30], loss:2125.5530
# number:1:epoch [2/30], loss:1920.8086
# number:1:epoch [2/30], loss:1968.3461
# number:1:epoch [2/30], loss:2036.7456
# number:1:epoch [2/30], loss:2076.4751
# number:1:epoch [2/30], loss:1884.6785
# number:1:epoch [2/30], loss:1956.0834
# number:1:epoch [2/30], loss:1887.2122
# number:1:epoch [2/30], loss:1972.3718
# number:1:epoch [2/30], loss:2054.4023
# number:1:epoch [2/30], loss:1833.0231
# number:1:epoch [2/30], loss:1930.3646
# number:1:epoch [2/30], loss:1828.6378
# number:1:epoch [2/30], loss:1839.0560
# number:1:epoch [2/30], loss:1993.4281
# number:1:epoch [2/30], loss:1805.1576
# number:1:epoch [2/30], loss:1976.2466
# number:1:epoch [2/30], loss:1882.6244
# number:1:epoch [2/30], loss:2049.7910
# number:1:epoch [2/30], loss:1938.0599
# number:1:epoch [2/30], loss:2108.2454
# number:1:epoch [2/30], loss:2027.6855
# number:1:epoch [2/30], loss:1908.6870
# number:1:epoch [2/30], loss:1815.0812
# number:1:epoch [2/30], loss:1846.4843
# number:1:epoch [2/30], loss:1930.6002
# number:1:epoch [2/30], loss:1919.9004
# number:1:epoch [2/30], loss:1874.5367
# number:1:epoch [2/30], loss:1862.4193
# number:1:epoch [2/30], loss:2080.4236
# number:1:epoch [2/30], loss:1824.1060
# number:1:epoch [2/30], loss:1968.6052
# number:1:epoch [2/30], loss:1902.9357
# number:1:epoch [2/30], loss:1838.9406
# number:1:epoch [2/30], loss:2044.0298
# number:1:epoch [2/30], loss:1932.2517
# number:1:epoch [2/30], loss:1986.0251
# number:1:epoch [2/30], loss:1879.9850
# number:1:epoch [2/30], loss:1748.8448
# number:1:epoch [2/30], loss:2097.2095
# number:1:epoch [2/30], loss:1856.5160
# number:1:epoch [2/30], loss:1907.5525
# number:1:epoch [2/30], loss:1820.6101
# number:1:epoch [2/30], loss:2088.7793
# number:1:epoch [2/30], loss:2047.7474
# number:1:epoch [2/30], loss:1962.3735
# number:1:epoch [2/30], loss:1827.0925
# number:1:epoch [2/30], loss:2049.0457
# number:1:epoch [2/30], loss:1961.7422
# number:1:epoch [2/30], loss:1860.7427
# number:1:epoch [2/30], loss:2176.3655
# number:1:epoch [2/30], loss:2033.9507
# number:1:epoch [2/30], loss:1956.5134
# number:1:epoch [2/30], loss:1834.9558
# number:1:epoch [2/30], loss:1958.2894
# number:1:epoch [2/30], loss:1929.8821
# number:1:epoch [2/30], loss:1851.7932
# number:1:epoch [2/30], loss:1838.8098
# number:1:epoch [2/30], loss:1860.8535
# number:1:epoch [2/30], loss:650.2318
# number:2:epoch [2/30], loss:4768.1812
# number:2:epoch [2/30], loss:4785.6064
# number:2:epoch [2/30], loss:4652.2432
# number:2:epoch [2/30], loss:4924.2578
# number:2:epoch [2/30], loss:4774.9341
# number:2:epoch [2/30], loss:4745.5718
# number:2:epoch [2/30], loss:4687.4502
# number:2:epoch [2/30], loss:4675.4668
# number:2:epoch [2/30], loss:4564.6548
# number:2:epoch [2/30], loss:4808.5796
# number:2:epoch [2/30], loss:4647.4146
# number:2:epoch [2/30], loss:4852.7793
# number:2:epoch [2/30], loss:4992.3203
# number:2:epoch [2/30], loss:4649.3618
# number:2:epoch [2/30], loss:4700.9980
# number:2:epoch [2/30], loss:4827.7363
# number:2:epoch [2/30], loss:4655.3403
# number:2:epoch [2/30], loss:4677.6353
# number:2:epoch [2/30], loss:4587.0415
# number:2:epoch [2/30], loss:4788.7227
# number:2:epoch [2/30], loss:4786.4614
# number:2:epoch [2/30], loss:4515.5815
# number:2:epoch [2/30], loss:4506.2656
# number:2:epoch [2/30], loss:4514.8750
# number:2:epoch [2/30], loss:4690.9355
# number:2:epoch [2/30], loss:4669.9819
# number:2:epoch [2/30], loss:4567.3979
# number:2:epoch [2/30], loss:4502.6812
# number:2:epoch [2/30], loss:4456.3608
# number:2:epoch [2/30], loss:4590.7373
# number:2:epoch [2/30], loss:4673.2075
# number:2:epoch [2/30], loss:4617.6328
# number:2:epoch [2/30], loss:4569.3164
# number:2:epoch [2/30], loss:4501.1504
# number:2:epoch [2/30], loss:4632.3774
# number:2:epoch [2/30], loss:4445.6025
# number:2:epoch [2/30], loss:4511.6602
# number:2:epoch [2/30], loss:4609.5801
# number:2:epoch [2/30], loss:4601.1294
# number:2:epoch [2/30], loss:4488.1880
# number:2:epoch [2/30], loss:4572.2705
# number:2:epoch [2/30], loss:4368.2236
# number:2:epoch [2/30], loss:4577.9194
# number:2:epoch [2/30], loss:4302.3770
# number:2:epoch [2/30], loss:4351.3110
# number:2:epoch [2/30], loss:4406.5278
# number:2:epoch [2/30], loss:4467.5376
# number:2:epoch [2/30], loss:4444.6226
# number:2:epoch [2/30], loss:4547.0435
# number:2:epoch [2/30], loss:4642.1411
# number:2:epoch [2/30], loss:4508.0132
# number:2:epoch [2/30], loss:4635.4609
# number:2:epoch [2/30], loss:4561.1860
# number:2:epoch [2/30], loss:4341.2368
# number:2:epoch [2/30], loss:4378.1245
# number:2:epoch [2/30], loss:4446.3452
# number:2:epoch [2/30], loss:4449.8438
# number:2:epoch [2/30], loss:4482.4644
# number:2:epoch [2/30], loss:4356.0259
# number:2:epoch [2/30], loss:4360.8018
# number:2:epoch [2/30], loss:4421.8013
# number:2:epoch [2/30], loss:4471.5518
# number:2:epoch [2/30], loss:4637.8774
# number:2:epoch [2/30], loss:4490.1045
# number:2:epoch [2/30], loss:4289.3691
# number:2:epoch [2/30], loss:4398.0747
# number:2:epoch [2/30], loss:4462.8140
# number:2:epoch [2/30], loss:4336.7529
# number:2:epoch [2/30], loss:4312.3604
# number:2:epoch [2/30], loss:4644.5181
# number:2:epoch [2/30], loss:4328.2988
# number:2:epoch [2/30], loss:4416.8711
# number:2:epoch [2/30], loss:4431.2261
# number:2:epoch [2/30], loss:4452.7881
# number:2:epoch [2/30], loss:4443.2710
# number:2:epoch [2/30], loss:4419.6133
# number:2:epoch [2/30], loss:4380.5278
# number:2:epoch [2/30], loss:4253.0381
# number:2:epoch [2/30], loss:4343.3364
# number:2:epoch [2/30], loss:4546.5166
# number:2:epoch [2/30], loss:4481.1709
# number:2:epoch [2/30], loss:4210.8291
# number:2:epoch [2/30], loss:4319.3467
# number:2:epoch [2/30], loss:4548.1245
# number:2:epoch [2/30], loss:4441.4224
# number:2:epoch [2/30], loss:4424.1562
# number:2:epoch [2/30], loss:3900.6858
# number:3:epoch [2/30], loss:4395.4492
# number:3:epoch [2/30], loss:4351.1313
# number:3:epoch [2/30], loss:4420.8267
# number:3:epoch [2/30], loss:4416.4067
# number:3:epoch [2/30], loss:4225.4189
# number:3:epoch [2/30], loss:4426.2295
# number:3:epoch [2/30], loss:4329.7847
# number:3:epoch [2/30], loss:4237.6636
# number:3:epoch [2/30], loss:4399.1108
# number:3:epoch [2/30], loss:4441.9121
# number:3:epoch [2/30], loss:4489.3057
# number:3:epoch [2/30], loss:4269.2520
# number:3:epoch [2/30], loss:4577.5259
# number:3:epoch [2/30], loss:4487.9868
# number:3:epoch [2/30], loss:4341.7041
# number:3:epoch [2/30], loss:4237.6455
# number:3:epoch [2/30], loss:4342.8066
# number:3:epoch [2/30], loss:4271.1704
# number:3:epoch [2/30], loss:4360.5635
# number:3:epoch [2/30], loss:4424.3711
# number:3:epoch [2/30], loss:4576.7627
# number:3:epoch [2/30], loss:4361.7896
# number:3:epoch [2/30], loss:4469.1753
# number:3:epoch [2/30], loss:4496.6528
# number:3:epoch [2/30], loss:4329.2446
# number:3:epoch [2/30], loss:4398.5190
# number:3:epoch [2/30], loss:4305.3584
# number:3:epoch [2/30], loss:4521.6006
# number:3:epoch [2/30], loss:4125.1592
# number:3:epoch [2/30], loss:4425.7896
# number:3:epoch [2/30], loss:4348.5483
# number:3:epoch [2/30], loss:4337.4126
# number:3:epoch [2/30], loss:4432.0776
# number:3:epoch [2/30], loss:4073.5393
# number:3:epoch [2/30], loss:4332.8721
# number:3:epoch [2/30], loss:4307.3125
# number:3:epoch [2/30], loss:4401.0933
# number:3:epoch [2/30], loss:4270.3652
# number:3:epoch [2/30], loss:4325.3247
# number:3:epoch [2/30], loss:4146.5166
# number:3:epoch [2/30], loss:4252.4097
# number:3:epoch [2/30], loss:4393.3604
# number:3:epoch [2/30], loss:4302.8330
# number:3:epoch [2/30], loss:4263.2769
# number:3:epoch [2/30], loss:4017.6135
# number:3:epoch [2/30], loss:4296.2168
# number:3:epoch [2/30], loss:4314.1904
# number:3:epoch [2/30], loss:4186.9868
# number:3:epoch [2/30], loss:4297.4048
# number:3:epoch [2/30], loss:4210.0317
# number:3:epoch [2/30], loss:4314.6074
# number:3:epoch [2/30], loss:4218.9473
# number:3:epoch [2/30], loss:4156.2373
# number:3:epoch [2/30], loss:4346.7715
# number:3:epoch [2/30], loss:4320.7588
# number:3:epoch [2/30], loss:4188.7720
# number:3:epoch [2/30], loss:4208.5596
# number:3:epoch [2/30], loss:4072.6477
# number:3:epoch [2/30], loss:4392.1807
# number:3:epoch [2/30], loss:4129.0615
# number:3:epoch [2/30], loss:4172.9385
# number:3:epoch [2/30], loss:4342.5791
# number:3:epoch [2/30], loss:4245.4873
# number:3:epoch [2/30], loss:4233.5610
# number:3:epoch [2/30], loss:4144.5181
# number:3:epoch [2/30], loss:4329.3472
# number:3:epoch [2/30], loss:4182.3057
# number:3:epoch [2/30], loss:4117.6045
# number:3:epoch [2/30], loss:4196.6377
# number:3:epoch [2/30], loss:4117.5513
# number:3:epoch [2/30], loss:4181.9912
# number:3:epoch [2/30], loss:4075.7749
# number:3:epoch [2/30], loss:4231.2900
# number:3:epoch [2/30], loss:4153.7808
# number:3:epoch [2/30], loss:4137.2803
# number:3:epoch [2/30], loss:4313.9453
# number:3:epoch [2/30], loss:4045.6592
# number:3:epoch [2/30], loss:4161.9355
# number:3:epoch [2/30], loss:4028.6382
# number:3:epoch [2/30], loss:3957.6096
# number:3:epoch [2/30], loss:4179.0107
# number:3:epoch [2/30], loss:3968.1555
# number:3:epoch [2/30], loss:4112.8428
# number:3:epoch [2/30], loss:4163.4736
# number:3:epoch [2/30], loss:4029.5164
# number:3:epoch [2/30], loss:4088.2668
# number:3:epoch [2/30], loss:4269.6421
# number:3:epoch [2/30], loss:3946.2239
# number:3:epoch [2/30], loss:3966.8850
# number:3:epoch [2/30], loss:1878.5713
# number:4:epoch [2/30], loss:3936.6438
# number:4:epoch [2/30], loss:4013.4766
# number:4:epoch [2/30], loss:4214.2236
# number:4:epoch [2/30], loss:3910.9595
# number:4:epoch [2/30], loss:3893.8755
# number:4:epoch [2/30], loss:3964.4731
# number:4:epoch [2/30], loss:3997.4431
# number:4:epoch [2/30], loss:4095.9348
# number:4:epoch [2/30], loss:4047.4819
# number:4:epoch [2/30], loss:3999.9844
# number:4:epoch [2/30], loss:3954.2146
# number:4:epoch [2/30], loss:3872.5410
# number:4:epoch [2/30], loss:3911.6685
# number:4:epoch [2/30], loss:4035.3745
# number:4:epoch [2/30], loss:3858.7344
# number:4:epoch [2/30], loss:4077.2168
# number:4:epoch [2/30], loss:4114.0601
# number:4:epoch [2/30], loss:4144.8145
# number:4:epoch [2/30], loss:3975.7888
# ...
# number:5:epoch [30/30], loss:3240.0029
# number:5:epoch [30/30], loss:3243.9683
# number:5:epoch [30/30], loss:3220.2224
# number:5:epoch [30/30], loss:3150.1831
# number:5:epoch [30/30], loss:3261.3262
# number:5:epoch [30/30], loss:3267.3232
# number:5:epoch [30/30], loss:3212.4136
# number:5:epoch [30/30], loss:3120.8445
# number:5:epoch [30/30], loss:3220.1484
# number:5:epoch [30/30], loss:3176.0024
# number:5:epoch [30/30], loss:3404.9995
# number:5:epoch [30/30], loss:3233.4783
# number:5:epoch [30/30], loss:3298.8540
# number:5:epoch [30/30], loss:3226.6531
# number:5:epoch [30/30], loss:3223.0728
# number:5:epoch [30/30], loss:3252.3833
# number:5:epoch [30/30], loss:3193.5586
# number:5:epoch [30/30], loss:3194.7681
# number:5:epoch [30/30], loss:3229.6885
# number:5:epoch [30/30], loss:3132.6902
# number:5:epoch [30/30], loss:3110.6221
# number:5:epoch [30/30], loss:3193.2749
# number:5:epoch [30/30], loss:3211.6409
# number:5:epoch [30/30], loss:3201.1646
# number:5:epoch [30/30], loss:3308.1462
# number:5:epoch [30/30], loss:3102.6255
# number:5:epoch [30/30], loss:3374.1833
# number:5:epoch [30/30], loss:3261.6565
# number:5:epoch [30/30], loss:3231.0020
# number:5:epoch [30/30], loss:3182.3140
# number:5:epoch [30/30], loss:3228.1025
# number:5:epoch [30/30], loss:3093.3989
# number:5:epoch [30/30], loss:3171.5249
# number:5:epoch [30/30], loss:3090.1470
# number:5:epoch [30/30], loss:3166.5640
# number:5:epoch [30/30], loss:3264.9167
# number:5:epoch [30/30], loss:3249.6826
# number:5:epoch [30/30], loss:3235.2727
# number:5:epoch [30/30], loss:3319.8079
# number:5:epoch [30/30], loss:3211.5659
# number:5:epoch [30/30], loss:3275.4348
# number:5:epoch [30/30], loss:3139.6260
# number:5:epoch [30/30], loss:3253.5908
# number:5:epoch [30/30], loss:3241.7646
# number:5:epoch [30/30], loss:3271.4392
# number:5:epoch [30/30], loss:3214.4487
# number:5:epoch [30/30], loss:3233.7656
# number:5:epoch [30/30], loss:3185.2393
# number:5:epoch [30/30], loss:3267.4321
# number:5:epoch [30/30], loss:3222.8945
# number:5:epoch [30/30], loss:3213.9495
# number:5:epoch [30/30], loss:3270.6384
# number:5:epoch [30/30], loss:3056.0872
# number:5:epoch [30/30], loss:3256.3254
# number:5:epoch [30/30], loss:3228.0605
# number:5:epoch [30/30], loss:3262.1909
# number:5:epoch [30/30], loss:3154.2207
# number:5:epoch [30/30], loss:744.9982
# number:6:epoch [30/30], loss:2951.7991
# number:6:epoch [30/30], loss:2820.3335
# number:6:epoch [30/30], loss:2935.3345
# number:6:epoch [30/30], loss:2871.3423
# number:6:epoch [30/30], loss:2937.3733
# number:6:epoch [30/30], loss:2821.9512
# number:6:epoch [30/30], loss:2900.1748
# number:6:epoch [30/30], loss:3018.7808
# number:6:epoch [30/30], loss:2800.1643
# number:6:epoch [30/30], loss:2989.9946
# number:6:epoch [30/30], loss:3009.3833
# number:6:epoch [30/30], loss:2864.9072
# number:6:epoch [30/30], loss:2874.5808
# number:6:epoch [30/30], loss:2938.6594
# number:6:epoch [30/30], loss:2862.1912
# number:6:epoch [30/30], loss:2997.4932
# number:6:epoch [30/30], loss:2966.8635
# number:6:epoch [30/30], loss:2790.3616
# number:6:epoch [30/30], loss:2928.6904
# number:6:epoch [30/30], loss:2882.1174
# number:6:epoch [30/30], loss:2764.6313
# number:6:epoch [30/30], loss:2883.4329
# number:6:epoch [30/30], loss:2847.2073
# number:6:epoch [30/30], loss:2877.9976
# number:6:epoch [30/30], loss:2828.0532
# number:6:epoch [30/30], loss:2835.7710
# number:6:epoch [30/30], loss:2881.2202
# number:6:epoch [30/30], loss:2814.9299
# number:6:epoch [30/30], loss:2986.9399
# number:6:epoch [30/30], loss:2809.4529
# number:6:epoch [30/30], loss:2813.9500
# number:6:epoch [30/30], loss:2980.5161
# number:6:epoch [30/30], loss:2990.2437
# number:6:epoch [30/30], loss:2974.6018
# number:6:epoch [30/30], loss:2833.4492
# number:6:epoch [30/30], loss:2917.5266
# number:6:epoch [30/30], loss:2800.1392
# number:6:epoch [30/30], loss:2769.8726
# number:6:epoch [30/30], loss:2934.6550
# number:6:epoch [30/30], loss:2940.0190
# number:6:epoch [30/30], loss:2849.9114
# number:6:epoch [30/30], loss:2851.3025
# number:6:epoch [30/30], loss:2926.5208
# number:6:epoch [30/30], loss:2914.8745
# number:6:epoch [30/30], loss:3146.0596
# number:6:epoch [30/30], loss:2710.8301
# number:6:epoch [30/30], loss:2808.1260
# number:6:epoch [30/30], loss:2882.8228
# number:6:epoch [30/30], loss:2937.6963
# number:6:epoch [30/30], loss:2966.6636
# number:6:epoch [30/30], loss:2868.2183
# number:6:epoch [30/30], loss:2937.2859
# number:6:epoch [30/30], loss:2927.6848
# number:6:epoch [30/30], loss:2957.7383
# number:6:epoch [30/30], loss:2774.8430
# number:6:epoch [30/30], loss:2933.3594
# number:6:epoch [30/30], loss:2950.0171
# number:6:epoch [30/30], loss:2933.9741
# number:6:epoch [30/30], loss:2775.2219
# number:6:epoch [30/30], loss:3001.4446
# number:6:epoch [30/30], loss:2948.1230
# number:6:epoch [30/30], loss:2854.5164
# number:6:epoch [30/30], loss:2746.2563
# number:6:epoch [30/30], loss:2881.4209
# number:6:epoch [30/30], loss:3080.7832
# number:6:epoch [30/30], loss:2995.2217
# number:6:epoch [30/30], loss:2892.2959
# number:6:epoch [30/30], loss:2873.6357
# number:6:epoch [30/30], loss:2942.5369
# number:6:epoch [30/30], loss:2834.6750
# number:6:epoch [30/30], loss:2927.0649
# number:6:epoch [30/30], loss:2841.0220
# number:6:epoch [30/30], loss:2939.1084
# number:6:epoch [30/30], loss:2896.2681
# number:6:epoch [30/30], loss:2940.1528
# number:6:epoch [30/30], loss:2862.1921
# number:6:epoch [30/30], loss:2950.1040
# number:6:epoch [30/30], loss:2976.1274
# number:6:epoch [30/30], loss:2833.8853
# number:6:epoch [30/30], loss:2825.8760
# number:6:epoch [30/30], loss:2988.7690
# number:6:epoch [30/30], loss:2819.2175
# number:6:epoch [30/30], loss:2919.8345
# number:6:epoch [30/30], loss:2895.5684
# number:6:epoch [30/30], loss:2822.2349
# number:6:epoch [30/30], loss:2878.2715
# number:6:epoch [30/30], loss:320.0856
# number:7:epoch [30/30], loss:2545.9673
# number:7:epoch [30/30], loss:2579.7793
# number:7:epoch [30/30], loss:2546.6833
# number:7:epoch [30/30], loss:2591.7490
# number:7:epoch [30/30], loss:2528.9307
# number:7:epoch [30/30], loss:2483.3611
# number:7:epoch [30/30], loss:2555.1963
# number:7:epoch [30/30], loss:2626.9443
# number:7:epoch [30/30], loss:2602.1152
# number:7:epoch [30/30], loss:2617.3318
# number:7:epoch [30/30], loss:2517.9094
# number:7:epoch [30/30], loss:2583.9006
# number:7:epoch [30/30], loss:2572.8889
# number:7:epoch [30/30], loss:2534.1548
# number:7:epoch [30/30], loss:2666.4819
# number:7:epoch [30/30], loss:2491.9890
# number:7:epoch [30/30], loss:2519.4695
# number:7:epoch [30/30], loss:2489.6653
# number:7:epoch [30/30], loss:2502.3093
# number:7:epoch [30/30], loss:2572.4319
# number:7:epoch [30/30], loss:2584.7078
# number:7:epoch [30/30], loss:2542.7178
# number:7:epoch [30/30], loss:2567.3477
# number:7:epoch [30/30], loss:2462.9062
# number:7:epoch [30/30], loss:2589.8040
# number:7:epoch [30/30], loss:2614.3079
# number:7:epoch [30/30], loss:2632.3293
# number:7:epoch [30/30], loss:2566.3533
# number:7:epoch [30/30], loss:2479.5791
# number:7:epoch [30/30], loss:2559.1572
# number:7:epoch [30/30], loss:2486.0393
# number:7:epoch [30/30], loss:2582.0317
# number:7:epoch [30/30], loss:2596.2742
# number:7:epoch [30/30], loss:2534.5613
# number:7:epoch [30/30], loss:2637.4277
# number:7:epoch [30/30], loss:2430.2595
# number:7:epoch [30/30], loss:2533.0088
# number:7:epoch [30/30], loss:2492.0559
# number:7:epoch [30/30], loss:2526.7002
# number:7:epoch [30/30], loss:2501.1301
# number:7:epoch [30/30], loss:2612.0901
# number:7:epoch [30/30], loss:2584.6294
# number:7:epoch [30/30], loss:2487.1404
# number:7:epoch [30/30], loss:2587.6313
# number:7:epoch [30/30], loss:2549.1995
# number:7:epoch [30/30], loss:2703.0244
# number:7:epoch [30/30], loss:2673.1382
# number:7:epoch [30/30], loss:2516.7703
# number:7:epoch [30/30], loss:2618.5396
# number:7:epoch [30/30], loss:2565.7793
# number:7:epoch [30/30], loss:2606.6196
# number:7:epoch [30/30], loss:2604.6099
# number:7:epoch [30/30], loss:2475.3303
# number:7:epoch [30/30], loss:2518.4338
# number:7:epoch [30/30], loss:2451.5127
# number:7:epoch [30/30], loss:2518.0288
# number:7:epoch [30/30], loss:2489.9104
# number:7:epoch [30/30], loss:2510.1252
# number:7:epoch [30/30], loss:2635.3545
# number:7:epoch [30/30], loss:2536.3135
# number:7:epoch [30/30], loss:2628.1492
# number:7:epoch [30/30], loss:2510.6841
# number:7:epoch [30/30], loss:2547.7180
# number:7:epoch [30/30], loss:2566.3555
# number:7:epoch [30/30], loss:2492.1572
# number:7:epoch [30/30], loss:2488.0344
# number:7:epoch [30/30], loss:2467.8604
# number:7:epoch [30/30], loss:2635.8335
# number:7:epoch [30/30], loss:2385.6401
# number:7:epoch [30/30], loss:2572.5996
# number:7:epoch [30/30], loss:2645.9465
# number:7:epoch [30/30], loss:2502.5693
# number:7:epoch [30/30], loss:2502.8579
# number:7:epoch [30/30], loss:2508.5208
# number:7:epoch [30/30], loss:2591.8074
# number:7:epoch [30/30], loss:2575.1238
# number:7:epoch [30/30], loss:2714.0911
# number:7:epoch [30/30], loss:2494.7710
# number:7:epoch [30/30], loss:2552.8042
# number:7:epoch [30/30], loss:2495.0864
# number:7:epoch [30/30], loss:2503.3413
# number:7:epoch [30/30], loss:2516.0576
# number:7:epoch [30/30], loss:2653.1572
# number:7:epoch [30/30], loss:2554.7759
# number:7:epoch [30/30], loss:2492.9951
# number:7:epoch [30/30], loss:2509.7371
# number:7:epoch [30/30], loss:2488.6638
# number:7:epoch [30/30], loss:2603.5737
# number:7:epoch [30/30], loss:2630.3528
# number:7:epoch [30/30], loss:2613.5706
# number:7:epoch [30/30], loss:2532.5244
# number:7:epoch [30/30], loss:51.8063
# number:8:epoch [30/30], loss:3547.6140
# number:8:epoch [30/30], loss:3360.1511
# number:8:epoch [30/30], loss:3322.7588
# number:8:epoch [30/30], loss:3443.5298
# number:8:epoch [30/30], loss:3417.9888
# number:8:epoch [30/30], loss:3398.4915
# number:8:epoch [30/30], loss:3305.6357
# number:8:epoch [30/30], loss:3292.2622
# number:8:epoch [30/30], loss:3255.1152
# number:8:epoch [30/30], loss:3422.6570
# number:8:epoch [30/30], loss:3498.6694
# number:8:epoch [30/30], loss:3557.0645
# number:8:epoch [30/30], loss:3531.7759
# number:8:epoch [30/30], loss:3508.0369
# number:8:epoch [30/30], loss:3335.0828
# number:8:epoch [30/30], loss:3341.3787
# number:8:epoch [30/30], loss:3529.0603
# number:8:epoch [30/30], loss:3333.5371
# number:8:epoch [30/30], loss:3396.5750
# number:8:epoch [30/30], loss:3299.8638
# number:8:epoch [30/30], loss:3561.8462
# number:8:epoch [30/30], loss:3479.5354
# number:8:epoch [30/30], loss:3346.9229
# number:8:epoch [30/30], loss:3283.2139
# number:8:epoch [30/30], loss:3439.6943
# number:8:epoch [30/30], loss:3465.1924
# number:8:epoch [30/30], loss:3431.1545
# number:8:epoch [30/30], loss:3356.4985
# number:8:epoch [30/30], loss:3492.0872
# number:8:epoch [30/30], loss:3334.0991
# number:8:epoch [30/30], loss:3474.0164
# number:8:epoch [30/30], loss:3506.3760
# number:8:epoch [30/30], loss:3436.2495
# number:8:epoch [30/30], loss:3566.2756
# number:8:epoch [30/30], loss:3289.2134
# number:8:epoch [30/30], loss:3450.0420
# number:8:epoch [30/30], loss:3440.5442
# number:8:epoch [30/30], loss:3370.3008
# number:8:epoch [30/30], loss:3473.8975
# number:8:epoch [30/30], loss:3537.9041
# number:8:epoch [30/30], loss:3379.8345
# number:8:epoch [30/30], loss:3524.3804
# number:8:epoch [30/30], loss:3567.5630
# number:8:epoch [30/30], loss:3309.8247
# number:8:epoch [30/30], loss:3366.4683
# number:8:epoch [30/30], loss:3409.0972
# number:8:epoch [30/30], loss:3386.8875
# number:8:epoch [30/30], loss:3530.0229
# number:8:epoch [30/30], loss:3471.4644
# number:8:epoch [30/30], loss:3487.2903
# number:8:epoch [30/30], loss:3355.3936
# number:8:epoch [30/30], loss:3360.9014
# number:8:epoch [30/30], loss:3320.6741
# number:8:epoch [30/30], loss:3464.1045
# number:8:epoch [30/30], loss:3655.1917
# number:8:epoch [30/30], loss:3560.0850
# number:8:epoch [30/30], loss:3500.1958
# number:8:epoch [30/30], loss:3540.9434
# number:8:epoch [30/30], loss:3312.1575
# number:8:epoch [30/30], loss:3377.7681
# number:8:epoch [30/30], loss:3452.4731
# number:8:epoch [30/30], loss:3396.2598
# number:8:epoch [30/30], loss:3357.4204
# number:8:epoch [30/30], loss:3421.9868
# number:8:epoch [30/30], loss:3376.2717
# number:8:epoch [30/30], loss:3407.8635
# number:8:epoch [30/30], loss:3430.0337
# number:8:epoch [30/30], loss:3392.8755
# number:8:epoch [30/30], loss:3453.7781
# number:8:epoch [30/30], loss:3509.9500
# number:8:epoch [30/30], loss:3318.3750
# number:8:epoch [30/30], loss:3467.5540
# number:8:epoch [30/30], loss:3668.3689
# number:8:epoch [30/30], loss:3527.0298
# number:8:epoch [30/30], loss:3414.3179
# number:8:epoch [30/30], loss:3356.5828
# number:8:epoch [30/30], loss:3440.4705
# number:8:epoch [30/30], loss:3527.6519
# number:8:epoch [30/30], loss:3613.4409
# number:8:epoch [30/30], loss:3395.8076
# number:8:epoch [30/30], loss:3501.0513
# number:8:epoch [30/30], loss:3403.6145
# number:8:epoch [30/30], loss:3437.2412
# number:8:epoch [30/30], loss:3393.5264
# number:8:epoch [30/30], loss:3145.4644
# number:9:epoch [30/30], loss:2773.2041
# number:9:epoch [30/30], loss:2744.6453
# number:9:epoch [30/30], loss:2783.8906
# number:9:epoch [30/30], loss:2808.1565
# number:9:epoch [30/30], loss:2774.6992
# number:9:epoch [30/30], loss:2813.7524
# number:9:epoch [30/30], loss:2720.8032
# number:9:epoch [30/30], loss:2709.0657
# number:9:epoch [30/30], loss:2794.6023
# number:9:epoch [30/30], loss:2860.2314
# number:9:epoch [30/30], loss:2701.9275
# number:9:epoch [30/30], loss:2785.1975
# number:9:epoch [30/30], loss:2825.7927
# number:9:epoch [30/30], loss:2693.4639
# number:9:epoch [30/30], loss:2658.3052
# number:9:epoch [30/30], loss:2710.8406
# number:9:epoch [30/30], loss:2635.5872
# number:9:epoch [30/30], loss:2685.5632
# number:9:epoch [30/30], loss:2832.7607
# number:9:epoch [30/30], loss:2660.5332
# number:9:epoch [30/30], loss:2707.1042
# number:9:epoch [30/30], loss:2631.9934
# number:9:epoch [30/30], loss:2724.2703
# number:9:epoch [30/30], loss:2738.4114
# number:9:epoch [30/30], loss:2822.4792
# number:9:epoch [30/30], loss:2722.5413
# number:9:epoch [30/30], loss:2758.4917
# number:9:epoch [30/30], loss:2811.1616
# number:9:epoch [30/30], loss:2759.9441
# number:9:epoch [30/30], loss:2715.9902
# number:9:epoch [30/30], loss:2877.6626
# number:9:epoch [30/30], loss:2778.1987
# number:9:epoch [30/30], loss:2777.1670
# number:9:epoch [30/30], loss:2650.9497
# number:9:epoch [30/30], loss:2742.8679
# number:9:epoch [30/30], loss:2686.0527
# number:9:epoch [30/30], loss:3056.3267
# number:9:epoch [30/30], loss:2699.6484
# number:9:epoch [30/30], loss:2658.4824
# number:9:epoch [30/30], loss:2709.0562
# number:9:epoch [30/30], loss:2657.6636
# number:9:epoch [30/30], loss:2728.1292
# number:9:epoch [30/30], loss:2741.2742
# number:9:epoch [30/30], loss:2767.9346
# number:9:epoch [30/30], loss:2740.9202
# number:9:epoch [30/30], loss:2669.4199
# number:9:epoch [30/30], loss:2776.7463
# number:9:epoch [30/30], loss:2669.0789
# number:9:epoch [30/30], loss:2742.6831
# number:9:epoch [30/30], loss:2699.9702
# number:9:epoch [30/30], loss:2692.1946
# number:9:epoch [30/30], loss:2791.2754
# number:9:epoch [30/30], loss:2772.9819
# number:9:epoch [30/30], loss:2739.9749
# number:9:epoch [30/30], loss:2811.1304
# number:9:epoch [30/30], loss:2738.2913
# number:9:epoch [30/30], loss:2674.1667
# number:9:epoch [30/30], loss:2803.5071
# number:9:epoch [30/30], loss:2712.1150
# number:9:epoch [30/30], loss:2782.4314
# number:9:epoch [30/30], loss:2763.8413
# number:9:epoch [30/30], loss:2701.8623
# number:9:epoch [30/30], loss:2777.7883
# number:9:epoch [30/30], loss:2873.2517
# number:9:epoch [30/30], loss:2743.1218
# number:9:epoch [30/30], loss:2780.9937
# number:9:epoch [30/30], loss:2730.3066
# number:9:epoch [30/30], loss:2651.0503
# number:9:epoch [30/30], loss:2841.5239
# number:9:epoch [30/30], loss:2755.0320
# number:9:epoch [30/30], loss:2900.4343
# number:9:epoch [30/30], loss:2680.1956
# number:9:epoch [30/30], loss:2826.5056
# number:9:epoch [30/30], loss:2735.3909
# number:9:epoch [30/30], loss:2683.3735
# number:9:epoch [30/30], loss:2839.5149
# number:9:epoch [30/30], loss:2727.0464
# number:9:epoch [30/30], loss:2592.5764
# number:9:epoch [30/30], loss:2765.1863
# number:9:epoch [30/30], loss:2630.6865
# number:9:epoch [30/30], loss:2649.3196
# number:9:epoch [30/30], loss:2629.0469
# number:9:epoch [30/30], loss:2713.9312
# number:9:epoch [30/30], loss:2654.3020
# number:9:epoch [30/30], loss:2753.2444
# number:9:epoch [30/30], loss:2736.1760
# number:9:epoch [30/30], loss:2779.6108
# number:9:epoch [30/30], loss:699.6176

# %%
test()
# Out:
# c:\Users\22732\.conda\envs\AIwork\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# OOD Detection: Accuracy: 0.88, Precision: 1.00, Recall: 0.88, F1-score: 0.93
# In MNIST:Accuracy: 0.95, Precision: 0.95, Recall: 0.95, F1-score: 0.95

# %%
model_dict = {f'VAE_digit_{i}': vae.state_dict() for i, vae in enumerate(vaes)} 
torch.save(model_dict, 'VAEs.pth')
